# %%
def construire_sql(select_label, where_template, concepts_valeurs):

    select_clause = f"SELECT {select_label} FROM films"


    where_clause = where_template

    for concept, valeur in concepts_valeurs:
        if concept == "acteur":
            clause_acteur = f"(acteur1 = '{valeur}' OR acteur2 = '{valeur}' OR acteur3 = '{valeur}')"
            where_clause = where_clause.replace("<val>", clause_acteur, 1)
        elif concept == "annee":
            where_clause = where_clause.replace("<annee>", valeur, 1)
        else:
            where_clause = where_clause.replace("<val>", f"'{valeur}'", 1)

    requete_sql = f"{select_clause} WHERE {where_clause};"
    return requete_sql

# %%
##python

import pandas as pd
import sqlite3
import re
import json
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Perceptron
from sklearn.pipeline import Pipeline

def nettoyer_where(clause):
    clause = re.sub(r"'[^']*'", "'<val>'", clause)
    clause = re.sub(r"\d{4}", "<annee>", clause)
    return clause.lower().strip()

def extraire_labels(sql):
    select = re.search(r'select (.+?) from', sql, re.IGNORECASE)
    where = re.search(r'where (.+)', sql, re.IGNORECASE)
    select_label = select.group(1).strip().lower() if select else "UNKNOWN"
    where_label = nettoyer_where(where.group(1)) if where else "NONE"
    return select_label, where_label

def analyse_lexicale(requete, lexique):
    concepts_valeurs = []
    deja_vus = set()
    correspondances = []
    for concept, valeurs in lexique.items():
        for valeur in valeurs:
            if valeur.lower() in requete.lower():
                match = re.search(re.escape(valeur), requete, flags=re.IGNORECASE)
                if match:
                    correspondances.append((match.start(), valeur, concept))
    correspondances.sort()
    for _, valeur, concept in correspondances:
        if valeur.lower() not in deja_vus:
            deja_vus.add(valeur.lower())
            concept_label = "acteur" if concept.startswith("acteur") else concept
            concepts_valeurs.append((concept_label, valeur))
    return concepts_valeurs

def generer_where_sql(concepts_valeurs):
    clauses = []
    for concept, valeur in concepts_valeurs:
        if concept == "acteur":
            clause = f"(acteur1 = '{valeur}' OR acteur2 = '{valeur}' OR acteur3 = '{valeur}')"
        elif concept == "annee":
            clause = f"annee = {valeur}"
        else:
            clause = f"{concept} = '{valeur}'"
        clauses.append(clause)
    return " AND ".join(clauses)

def executer_requete_sqlite(select_clause, where_clause, conn):
    sql = f"SELECT {select_clause} FROM films WHERE {where_clause};"
    try:
        result = pd.read_sql_query(sql, conn)
        return sql, result
    except Exception as e:
        return sql, f"Erreur d'exécution : {e}"

def main():
    # Charger les données d'entraînement
    with open("queries_french_para.json", encoding="utf-8") as f:
        data = json.load(f)

    select_X, select_y, where_X, where_y = [], [], [], []

    for entry in data:
        sql = entry.get("sql", "")
        select_label, where_label = extraire_labels(sql)
        phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
        for phrase in phrases:
            select_X.append(phrase)
            select_y.append(select_label)
            where_X.append(phrase)
            where_y.append(where_label)

    pipeline_select = Pipeline([("vectorizer", CountVectorizer()), ("perceptron", Perceptron())])
    pipeline_select.fit(select_X, select_y)

    # Charger les données du CSV
    df = pd.read_csv("base_films_500.csv")
    conn = sqlite3.connect(":memory:")
    df.to_sql("films", conn, index=False, if_exists="replace")

    valeurs_concepts = {
        'titre': df['titre'].dropna().unique().tolist(),
        'realisateur': df['realisateur'].dropna().unique().tolist(),
        'annee': df['annee'].dropna().astype(str).unique().tolist(),
        'genre': df['genre'].dropna().unique().tolist(),
        'acteur1': df['acteur1'].dropna().unique().tolist(),
        'acteur2': df['acteur2'].dropna().unique().tolist(),
        'acteur3': df['acteur3'].dropna().unique().tolist()
    }

    while True:
        requete_naturelle = input("\nEntrez votre requête (ou tapez 'exit' pour quitter) :\n> ")
        if requete_naturelle.lower() == "exit":
            print("À bientôt !")
            break

        concepts_valeurs = analyse_lexicale(requete_naturelle, valeurs_concepts)
        select_pred = pipeline_select.predict([requete_naturelle])[0]
        where_clause = generer_where_sql(concepts_valeurs)
        requete_sql, resultat = executer_requete_sqlite(select_pred, where_clause, conn)

        print("\n--- Requête SQL générée ---")
        print(requete_sql)
        print("\n--- Résultat ---")
        if isinstance(resultat, pd.DataFrame):
            print(resultat.head(10))
        else:
            print(resultat)

if __name__ == "__main__":
    main()

# %%
select_pred = "titre"
where_pred = "(acteur1 = '<val>' OR acteur2 = '<val>' OR acteur3 = '<val>') AND (acteur1 = '<val>' OR acteur2 = '<val>' OR acteur3 = '<val>')"
concepts_vals = [('acteur', 'Meryl Streep'), ('acteur', 'Hugh Jackman')]

sql = construire_sql(select_pred, where_pred, concepts_vals)
print(sql)
# Out:
# SELECT titre FROM films WHERE (acteur1 = '(acteur1 = 'Meryl Streep' OR acteur2 = 'Meryl Streep' OR acteur3 = 'Meryl Streep')' OR acteur2 = '(acteur1 = 'Hugh Jackman' OR acteur2 = 'Hugh Jackman' OR acteur3 = 'Hugh Jackman')' OR acteur3 = '<val>') AND (acteur1 = '<val>' OR acteur2 = '<val>' OR acteur3 = '<val>');

# %%
import pandas as pd
import sqlite3
import re
import json
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Perceptron
from sklearn.pipeline import Pipeline


with open("queries_french_para.json", encoding="utf-8") as f:
    data = json.load(f)

def nettoyer_where(clause):
    clause = re.sub(r"'[^']*'", "'<val>'", clause)
    clause = re.sub(r"\d{4}", "<annee>", clause)
    return clause.lower().strip()

def extraire_labels(sql):
    select = re.search(r'select (.+?) from', sql, re.IGNORECASE)
    where = re.search(r'where (.+)', sql, re.IGNORECASE)
    select_label = select.group(1).strip().lower() if select else "UNKNOWN"
    where_label = nettoyer_where(where.group(1)) if where else "NONE"
    return select_label, where_label

select_X, select_y, where_X, where_y = [], [], [], []
for entry in data:
    sql = entry.get("sql", "")
    select_label, where_label = extraire_labels(sql)
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
    for phrase in phrases:
        select_X.append(phrase)
        select_y.append(select_label)
        where_X.append(phrase)
        where_y.append(where_label)


pipeline_select = Pipeline([("vectorizer", CountVectorizer()), ("perceptron", Perceptron())])
pipeline_select.fit(select_X, select_y)


df = pd.read_csv("base_films_500.csv")
conn = sqlite3.connect(":memory:")
df.to_sql("films", conn, index=False, if_exists="replace")


valeurs_concepts = {
    'titre': df['titre'].dropna().unique().tolist(),
    'realisateur': df['realisateur'].dropna().unique().tolist(),
    'annee': df['annee'].dropna().astype(str).unique().tolist(),
    'genre': df['genre'].dropna().unique().tolist(),
    'acteur1': df['acteur1'].dropna().unique().tolist(),
    'acteur2': df['acteur2'].dropna().unique().tolist(),
    'acteur3': df['acteur3'].dropna().unique().tolist()
}


def analyse_lexicale(requete, lexique):
    concepts_valeurs = []
    deja_vus = set()
    correspondances = []
    for concept, valeurs in lexique.items():
        for valeur in valeurs:
            if valeur.lower() in requete.lower():
                match = re.search(re.escape(valeur), requete, flags=re.IGNORECASE)
                if match:
                    correspondances.append((match.start(), valeur, concept))
    correspondances.sort()
    for _, valeur, concept in correspondances:
        if valeur.lower() not in deja_vus:
            deja_vus.add(valeur.lower())
            concept_label = "acteur" if concept.startswith("acteur") else concept
            concepts_valeurs.append((concept_label, valeur))
    return concepts_valeurs


def generer_where_sql(concepts_valeurs):
    clauses = []
    annees = []

    for concept, valeur in concepts_valeurs:
        if concept == "annee":
            annees.append(valeur)
        elif concept == "acteur":
            val = valeur
            clause = f"((acteur1 = '{val}' or acteur2 = '{val}' or acteur3 = '{val}'))"
            clauses.append(clause)
        else:
            clause = f"{concept} = '{valeur}'"
            clauses.append(clause)


    if len(annees) == 2:
        an1, an2 = sorted(annees)
        clauses.append(f"annee between {an1} and {an2}")
    elif len(annees) == 1:
        clauses.append(f"annee = {annees[0]}")

    return " AND ".join(clauses)



def executer_requete_sqlite(select_clause, where_clause):
    sql = f"SELECT {select_clause} FROM films WHERE {where_clause};"
    try:
        result = pd.read_sql_query(sql, conn)
        return sql, result
    except Exception as e:
        return sql, f"Erreur d'exécution : {e}"


requete_naturelle = "Je souhaiterais connaître les films où Meryl Streep et Hugh Jackman ont un rôle."
concepts_valeurs = analyse_lexicale(requete_naturelle, valeurs_concepts)
select_pred = pipeline_select.predict([requete_naturelle])[0]
where_clause = generer_where_sql(concepts_valeurs)
requete_sql, resultat = executer_requete_sqlite(select_pred, where_clause)

print("\n--- Requête SQL générée ---")
print(requete_sql)
print("\n--- Résultat ---")
print(resultat.head(10) if isinstance(resultat, pd.DataFrame) else resultat)
# Out:
# --- Requête SQL générée ---
# SELECT titre FROM films WHERE ((acteur1 = 'Meryl Streep' or acteur2 = 'Meryl Streep' or acteur3 = 'Meryl Streep')) AND ((acteur1 = 'Hugh Jackman' or acteur2 = 'Hugh Jackman' or acteur3 = 'Hugh Jackman'));
#
# --- Résultat ---
#                         titre
# 0  The Frozen Mission Project
# 1      The Frozen Memory Code
# 2        The Lost Secret Game

# %% [markdown]
# #Evaluation :
#
# #Evaluation quantitative :

# %%
import json
import re
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Perceptron

# === Charger les fichiers nécessaires
with open("queries_french_para.json", encoding="utf-8") as f:
    train_data = json.load(f)

with open("queries_french_para_eval.json", encoding="utf-8") as f:
    eval_data = json.load(f)

# === Fonction d’extraction de concepts depuis le SQL attendu
def extraire_concepts_from_sql(sql):
    sql = sql.lower()
    concepts = []
    if "titre" in sql: concepts.append("titre")
    if "realisateur" in sql: concepts.append("realisateur")
    if "annee" in sql: concepts.append("annee")
    if "genre" in sql: concepts.append("genre")
    if "acteur1" in sql or "acteur2" in sql or "acteur3" in sql:
        concepts.append("acteur")
    return list(set(concepts))

# === Analyse lexicale déjà existante
def analyse_lexicale(requete, lexique):
    concepts_valeurs = []
    deja_vus = set()
    correspondances = []
    for concept, valeurs in lexique.items():
        for valeur in valeurs:
            if valeur.lower() in requete.lower():
                match = re.search(re.escape(valeur), requete, flags=re.IGNORECASE)
                if match:
                    correspondances.append((match.start(), valeur, concept))
    correspondances.sort()
    for _, valeur, concept in correspondances:
        if valeur.lower() not in deja_vus:
            deja_vus.add(valeur.lower())
            concept_label = "acteur" if concept.startswith("acteur") else concept
            concepts_valeurs.append((concept_label, valeur))
    return concepts_valeurs

# === Préparation du lexique depuis le CSV
import pandas as pd
df = pd.read_csv("base_films_500.csv")

valeurs_concepts = {
    'titre': df['titre'].dropna().unique().tolist(),
    'realisateur': df['realisateur'].dropna().unique().tolist(),
    'annee': df['annee'].dropna().astype(str).unique().tolist(),
    'genre': df['genre'].dropna().unique().tolist(),
    'acteur1': df['acteur1'].dropna().unique().tolist(),
    'acteur2': df['acteur2'].dropna().unique().tolist(),
    'acteur3': df['acteur3'].dropna().unique().tolist()
}

# === Entraînement des modèles de classification SELECT/WHERE
def nettoyer_where(clause):
    clause = re.sub(r"'[^']*'", "'<val>'", clause)
    clause = re.sub(r"\d{4}", "<annee>", clause)
    return clause.lower().strip()

def extraire_labels(sql):
    select = re.search(r'select (.+?) from', sql, re.IGNORECASE)
    where = re.search(r'where (.+)', sql, re.IGNORECASE)
    select_label = select.group(1).strip().lower() if select else "UNKNOWN"
    where_label = nettoyer_where(where.group(1)) if where else "NONE"
    return select_label, where_label

select_X, select_y, where_X, where_y = [], [], [], []

for entry in train_data:
    sql = entry["sql"]
    select_label, where_label = extraire_labels(sql)
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
    for phrase in phrases:
        select_X.append(phrase)
        select_y.append(select_label)
        where_X.append(phrase)
        where_y.append(where_label)

# === Modèles Perceptron
pipeline_select = Pipeline([("vec", CountVectorizer()), ("clf", Perceptron())])
pipeline_where = Pipeline([("vec", CountVectorizer()), ("clf", Perceptron())])
pipeline_select.fit(select_X, select_y)
pipeline_where.fit(where_X, where_y)

# === Évaluation 1 : Concepts / Valeurs
print("\n🔍 Évaluation 1 : Extraction des concepts/valeurs\n")
total = 0
correct = 0

for entry in eval_data:
    sql_attendu = entry["sql"]
    concepts_attendus = set(extraire_concepts_from_sql(sql_attendu))
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
    for phrase in phrases:
        concepts_extraits = set([c for c, _ in analyse_lexicale(phrase, valeurs_concepts)])
        if concepts_attendus == concepts_extraits:
            correct += 1
        else:
            print(f"❌ Phrase : {phrase}")
            print(f"Attendu : {concepts_attendus}")
            print(f"Extrait : {concepts_extraits}\n")
        total += 1

print(f"\n✅ Précision concept/valeurs : {correct}/{total} = {correct / total * 100:.2f}%")

# === Évaluation 2 : SELECT + WHERE
print("\n🧠 Évaluation 2 : Intention SELECT et WHERE\n")
select_correct, where_correct = 0, 0
total_intent = 0

for entry in eval_data:
    sql_attendu = entry["sql"]
    select_gold, where_gold = extraire_labels(sql_attendu)
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
    for phrase in phrases:
        select_pred = pipeline_select.predict([phrase])[0]
        where_pred = pipeline_where.predict([phrase])[0]
        if select_pred.strip().lower() == select_gold:
            select_correct += 1
        else:
            print(f"❌ SELECT - {phrase}")
            print(f"Gold : {select_gold} | Pred : {select_pred}")
        if where_pred.strip().lower() == where_gold:
            where_correct += 1
        else:
            print(f"❌ WHERE - {phrase}")
            print(f"Gold : {where_gold} | Pred : {where_pred}")
        total_intent += 1

print(f"\n✅ Précision SELECT : {select_correct}/{total_intent} = {select_correct / total_intent * 100:.2f}%")
print(f"✅ Précision WHERE  : {where_correct}/{total_intent} = {where_correct / total_intent * 100:.2f}%")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous me donner l'année des films intitulés The Last Empire Story ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que vous pourriez me dire en quelle année sont sortis les films The Last Empire Story ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître l'année de sortie des films appelés The Last Empire Story.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous m'indiquer l'année des films portant le titre The Last Empire Story ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Donnez-moi, s'il vous plaît, l'année des films qui s'appellent The Last Empire Story.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer l'année des films dont le titre est The Silent Journey Protocol.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous me dire en quelle année a été réalisé le film intitulé The Silent Journey Protocol ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous m'indiquer l'année de sortie des films appelés The Silent Journey Protocol ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir quelle est l'année des films qui portent le titre The Silent Journey Protocol.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que vous pouvez me donner l'année de production des films nommés The Silent Journey Protocol ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Merci de bien vouloir fournir l'année des films intitulés The Silent Journey Protocol.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Tom Hanks joue et où Brad Pitt joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me montrer les titres des films avec Tom Hanks et Brad Pitt ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi s'il vous plaît les films où Tom Hanks et Brad Pitt sont présents.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais savoir quels films incluent Tom Hanks et Brad Pitt.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Est-ce que vous pouvez me donner les titres des films mettant en vedette Tom Hanks et Brad Pitt ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me dire quels films ont Tom Hanks et Brad Pitt au casting ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer les titres des films où Tom Cruise joue et dont le genre est Thriller.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous s'il vous plaît me donner les titres des films dans lesquels Tom Cruise apparaît et qui sont des thrillers ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Merci de me fournir les titres des films avec Tom Cruise, spécifiquement dans le genre Thriller.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films où Tom Cruise est présent et qui appartiennent au genre Thriller.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Peux-tu me dire quels films avec Tom Cruise sont classés comme thrillers ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Donnez-moi les titres des films à suspense où Tom Cruise a un rôle, s'il vous plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer l'année des films dont le titre est The Dark Shadow Project.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous m'indiquer l'année des films intitulés The Dark Shadow Project ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire en quelle année est sorti le film The Dark Shadow Project ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir quel est l'année du film The Dark Shadow Project.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Merci de me fournir l'année de sortie des films The Dark Shadow Project.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : S'il vous plaît, pourriez-vous partager l'année pour les films avec le titre The Dark Shadow Project ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Golden Journey Saga.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Qui est le réalisateur du film intitulé The Golden Journey Saga ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire qui a réalisé le film The Golden Journey Saga ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir qui est le réalisateur des films appelés The Golden Journey Saga.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu m'indiquer le nom du réalisateur du film qui s'appelle The Golden Journey Saga ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : S'il te plaît, renseigne-moi sur le réalisateur des films ayant pour titre The Golden Journey Saga.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer les titres des films dans lesquels Emily Blunt joue et dont le genre est la Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Montrez-moi les films où Emily Blunt apparaît et qui sont de genre Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les titres des films d'Emily Blunt dans le genre Romance ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais connaître les films avec Emily Blunt qui sont classés comme des Romances.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous indiquer les films d'Emily Blunt en Romance ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Quels sont les titres des films d'Emily Blunt dans le style romantique ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer les titres des films où Sandra Bullock joue et où Natalie Portman joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les titres des films avec Sandra Bullock et Natalie Portman ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les films mettant en vedette Sandra Bullock et Natalie Portman, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me montrer les films dans lesquels jouent Sandra Bullock et Natalie Portman ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais avoir les titres des films avec Sandra Bullock et Natalie Portman, merci.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Quels sont les films où Sandra Bullock et Natalie Portman apparaissent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Jennifer Lawrence joue et Cate Blanchett joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me donner le titre des films dans lesquels Jennifer Lawrence et Cate Blanchett apparaissent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : S'il vous plaît, indiquez-moi les films avec Jennifer Lawrence et Cate Blanchett.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films qui mettent en vedette Jennifer Lawrence et Cate Blanchett.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourrais-je avoir la liste des films dans lesquels Jennifer Lawrence et Cate Blanchett jouent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Merci de me montrer les titres des films où Jennifer Lawrence et Cate Blanchett sont présentes.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Anne Hathaway joue et dont le genre est Animation.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Montrez-moi les titres des films d'animation avec Anne Hathaway, s'il vous plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous me dire quels films d'animation avec Anne Hathaway existent ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je cherche les titres des films d'animation dans lesquels Anne Hathaway apparaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Avez-vous une liste des films d'animation où Anne Hathaway joue ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pouvez-vous me fournir les titres des films d'animation mettant en vedette Anne Hathaway ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Lost Dream Chronicles.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Montrez-moi le réalisateur de The Lost Dream Chronicles, s'il vous plaît.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire qui est le réalisateur de The Lost Dream Chronicles ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Qui est le réalisateur des films intitulés The Lost Dream Chronicles ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous me communiquer le nom du réalisateur pour The Lost Dream Chronicles ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je voudrais savoir qui a réalisé The Lost Dream Chronicles.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Frozen Dream Chronicles.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire qui est le réalisateur des films intitulés The Frozen Dream Chronicles ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu m'indiquer le nom du réalisateur des films appelés The Frozen Dream Chronicles ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir qui est le réalisateur des films intitulés The Frozen Dream Chronicles.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Qui est le réalisateur des films portant le titre The Frozen Dream Chronicles, s'il vous plaît ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourrais-je obtenir des informations sur le réalisateur des films The Frozen Dream Chronicles ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer toutes les informations des films dont le titre contient Infinite, triés par année par ordre décroissant.
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Montrez-moi toutes les infos des films ayant 'Infinite' dans le titre, classés par année décroissante.
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Pourriez-vous afficher toutes les informations sur les films avec 'Infinite' dans leur titre, triés de la plus récente à la plus ancienne année ?
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Je voudrais voir toutes les informations sur les films avec 'Infinite' dans le titre, de l'année la plus récente à la plus ancienne.
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Merci de bien vouloir me fournir toutes les informations des films dont le titre comprend 'Infinite', organisés par année descendante.
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Je suis intéressé par les films ayant 'Infinite' dans le titre. Pouvez-vous les trier par année, de la plus récente à la plus ancienne ?
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Veuillez me montrer l'année des films dont le titre est The Infinite Journey Game.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me donner l'année des films intitulés The Infinite Journey Game ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître l'année des films ayant pour titre The Infinite Journey Game.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me dire quelle est l'année des films nommés The Infinite Journey Game ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-il possible de connaître l'année des films sous le titre The Infinite Journey Game ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Merci de m'informer de l'année des films qui portent le titre The Infinite Journey Game.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le titre des films dans lesquels Brad Pitt joue et Keanu Reeves joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous m'indiquer les titres des films où Brad Pitt et Keanu Reeves apparaissent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Est-ce que vous pouvez me dire les titres des films avec Brad Pitt et Keanu Reeves ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais savoir quels sont les films avec Brad Pitt et Keanu Reeves.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les noms des films où jouent Brad Pitt et Keanu Reeves ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les films dans lesquels Brad Pitt et Keanu Reeves sont présents, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer l'année des films dont le titre est The Golden Dream Chronicles.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous m'indiquer l'année des films intitulés The Golden Dream Chronicles ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous me dire en quelle année est sorti le film The Golden Dream Chronicles ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Montrez-moi l'année de sortie du film The Golden Dream Chronicles, s'il vous plaît.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je voudrais savoir quelle est l'année des films portant le titre The Golden Dream Chronicles.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Quel est l'année de sortie des films ayant pour titre The Golden Dream Chronicles ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le titre des films dans lesquels Zendaya joue et dont le genre est Animation.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Montrez-moi les titres des films avec Zendaya qui sont de genre Animation.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous me donner les titres des films où Zendaya apparaît et qui sont classés comme Animation ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais voir les titres des films d'Animation avec Zendaya, s'il vous plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous s'il vous plaît me montrer les titres des films animés dans lesquels Zendaya joue ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Auriez-vous la gentillesse de me fournir les titres des films d'Animation avec Zendaya ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur du film intitulé The Lost Promise Code.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me dire qui est le réalisateur du film The Lost Promise Code ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourrais-je connaître le nom du réalisateur de The Lost Promise Code ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir qui a réalisé le film The Lost Promise Code.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que tu sais qui est le réalisateur du film The Lost Promise Code ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous m'indiquer le nom du réalisateur de The Lost Promise Code, s'il vous plaît ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer toutes les informations des films dont le titre contient 'Last', triés par année par ordre décroissant.
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Montrez-moi toutes les infos sur les films avec 'Last' dans le titre, organisés par année, du plus récent au plus ancien.
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Pourriez-vous fournir toutes les informations des films ayant 'Last' dans leur titre, classés par année décroissante ?
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : J'aimerais voir toutes les données des films qui contiennent 'Last' dans le titre, en les triant par année, du plus récent au moins récent.
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : S'il vous plaît, affichez toutes les informations concernant les films avec 'Last' dans leurs titres, classées par année décroissante.
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Pouvez-vous s'il vous plaît me donner toutes les informations sur les films avec 'Last' dans le titre, triés par année de manière décroissante ?
# Attendu : {'titre', 'annee'}
# Extrait : set()
#
# ❌ Phrase : Veuillez me montrer les acteurs des films où l'année est 1987.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Montrez-moi les acteurs des films de 1987, s'il vous plaît.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Pourriez-vous afficher les acteurs des films sortis en 1987 ?
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : J'aimerais voir les acteurs des films de 1987, merci.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Est-ce que vous pouvez me donner les acteurs des films de l'année 1987 ?
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Pouvez-vous me lister les acteurs des films datant de 1987 ?
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Veuillez me montrer l'année des films dont le titre est The Dark Mission Story.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous m'indiquer l'année des films intitulés The Dark Mission Story ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je voudrais savoir quelle année correspond au film intitulé The Dark Mission Story.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que vous pourriez m'informer sur l'année des films portant le titre The Dark Mission Story ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire en quelle année le film The Dark Mission Story est sorti ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître l'année de sortie des films qui s'appellent The Dark Mission Story.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer l'année des films dont le titre est The Frozen Memory Legacy.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous indiquer l'année des films intitulés The Frozen Memory Legacy ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire en quelle année le film The Frozen Memory Legacy a été réalisé ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que vous pourriez me donner l'année de sortie du film The Frozen Memory Legacy ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous m'informer de l'année du film The Frozen Memory Legacy, s'il vous plaît ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître l'année du film The Frozen Memory Legacy, merci !
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer les titres des films dans lesquels Zendaya joue et Robert De Niro joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous s'il vous plaît me donner les titres des films avec Zendaya et Robert De Niro ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je souhaiterais connaître les films où Zendaya et Robert De Niro apparaissent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les titres des films où Zendaya et Robert De Niro jouent, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Quels sont les films qui mettent en vedette Zendaya et Robert De Niro ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais voir les titres des films où Zendaya et Robert De Niro figurent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Tom Cruise joue et Matt Damon joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me donner les titres des films avec Tom Cruise et Matt Damon ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi s'il vous plaît les titres des films dans lesquels Tom Cruise et Matt Damon apparaissent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Est-ce que vous pouvez me dire quels films mettent en vedette Tom Cruise et Matt Damon ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais savoir les titres des films où Tom Cruise ainsi que Matt Damon jouent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Peux-tu me montrer les films avec Tom Cruise et Matt Damon dans le casting ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer les titres des films dans lesquels Chris Evans joue et qui sont de genre Action.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Peux-tu me donner les titres des films avec Chris Evans qui sont des films d'action ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourrais-je avoir les titres des films d'action où Chris Evans apparaît ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais connaître les films d'action avec Chris Evans, quels sont leurs titres ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je voudrais savoir quels films d'action avec Chris Evans existent. Peux-tu les lister ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous me fournir les titres des films de genre Action mettant en vedette Chris Evans ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer les titres des films où Natalie Portman joue et où Sandra Bullock joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pouvez-vous m'indiquer les titres des films avec Natalie Portman et Sandra Bullock ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me dire quels films comportent Natalie Portman et Sandra Bullock ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je souhaiterais connaître les films où Natalie Portman et Sandra Bullock apparaissent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Avez-vous la liste des films dans lesquels jouent Natalie Portman et Sandra Bullock ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les titres des films avec Natalie Portman et Sandra Bullock, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer l'année des films portant le titre The Last Empire Protocol.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Montrez-moi l'année des films intitulés The Last Empire Protocol, s'il vous plaît.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire quelle année a été faite le film The Last Empire Protocol ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître l'année de sortie du film The Last Empire Protocol.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me dire l'année à laquelle le film The Last Empire Protocol est sorti ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je voudrais savoir l'année du film intitulé The Last Empire Protocol.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer toutes les informations des films dont l'année se situe entre 1950 et 2028.
# Attendu : {'annee'}
# Extrait : set()
#
# ❌ Phrase : Montrez-moi toutes les informations sur les films sortis entre 1950 et 2028.
# Attendu : {'annee'}
# Extrait : set()
#
# ❌ Phrase : Pourriez-vous me fournir toutes les informations relatives aux films de 1950 à 2028 ?
# Attendu : {'annee'}
# Extrait : set()
#
# ❌ Phrase : J'aimerais avoir accès à toutes les données des films entre 1950 et 2028, s'il vous plaît.
# Attendu : {'annee'}
# Extrait : set()
#
# ❌ Phrase : Auriez-vous l'amabilité de me montrer les informations des films dont l'année est comprise entre 1950 et 2028 ?
# Attendu : {'annee'}
# Extrait : set()
#
# ❌ Phrase : Je souhaiterais consulter toutes les informations sur les films publiés entre 1950 et 2028.
# Attendu : {'annee'}
# Extrait : set()
#
# ❌ Phrase : Veuillez me montrer l'année des films dont le titre est The Frozen Journey Saga.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous m'indiquer l'année des films appelés The Frozen Journey Saga ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître l'année des films intitulés The Frozen Journey Saga.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous afficher l'année des films qui s'appellent The Frozen Journey Saga ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Serait-il possible de fournir l'année des films portant le titre The Frozen Journey Saga ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Merci de me communiquer l'année des films qui ont pour titre The Frozen Journey Saga.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer les titres des films où Tom Cruise joue et le genre est Drame.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les titres des films dans lesquels Tom Cruise apparaît, et qui sont de genre Drame ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous afficher les titres des films avec Tom Cruise qui relèvent du Drame ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Merci de me communiquer les titres des films où Tom Cruise est présent et qui appartiennent au genre Drame.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films de Tom Cruise, spécifiquement ceux qui sont classés en tant que Drame.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous s'il vous plaît me fournir les titres des films de Tom Cruise dans le genre Drame ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Burning Memory Protocol.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me dire qui est le réalisateur des films intitulés The Burning Memory Protocol ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourrais-je savoir qui a réalisé les films appelés The Burning Memory Protocol ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître le nom du réalisateur des films ayant pour titre The Burning Memory Protocol.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que tu pourrais indiquer qui est le réalisateur des films de The Burning Memory Protocol ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Qui est le réalisateur des films qui s'appellent The Burning Memory Protocol, s'il te plaît ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Ryan Gosling joue et où Natalie Portman joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les titres des films dans lesquels Ryan Gosling et Natalie Portman apparaissent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films avec Ryan Gosling et Natalie Portman, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous indiquer les films où Ryan Gosling et Natalie Portman jouent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Merci de me dire quels films incluent Ryan Gosling et Natalie Portman.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je cherche les titres des films qui mettent en scène Ryan Gosling et Natalie Portman.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer les acteurs des films dont l'année est 1991.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Montrez-moi les acteurs des films sortis en 1991.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Pouvez-vous me donner la liste des acteurs pour les films de 1991 ?
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : J'aimerais connaître les acteurs des films de 1991, s'il vous plaît.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Pourriez-vous me montrer quels sont les acteurs des films de 1991 ?
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Je cherche les acteurs des films qui datent de 1991.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Veuillez me montrer les titres des films dans lesquels Charlize Theron et Emma Stone jouent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les titres des films avec Charlize Theron et Emma Stone, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les noms des films où Charlize Theron et Emma Stone apparaissent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais savoir quels films incluent Charlize Theron et Emma Stone.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Est-ce que vous pouvez me montrer les titres des films avec Charlize Theron et Emma Stone ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Quels sont les films dans lesquels Charlize Theron et Emma Stone jouent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Sandra Bullock joue et dont le genre est la Science-fiction.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les titres des films avec Sandra Bullock qui sont de science-fiction ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais savoir quels films de science-fiction avec Sandra Bullock existent.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous me montrer les titres des films de science-fiction où Sandra Bullock est à l'affiche ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films de science-fiction dans lesquels Sandra Bullock joue.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Merci de me fournir les titres des films de science-fiction avec Sandra Bullock.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films dans lesquels Leonardo DiCaprio joue et Joaquin Phoenix joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Peux-tu me donner les titres des films avec Leonardo DiCaprio et Joaquin Phoenix ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je voudrais connaître les titres des films où Leonardo DiCaprio et Joaquin Phoenix sont présents.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourrais-tu me montrer les films contenant Leonardo DiCaprio et Joaquin Phoenix ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Serait-il possible de me fournir les titres des films avec Leonardo DiCaprio et Joaquin Phoenix ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je cherche les titres de films où Leonardo DiCaprio et Joaquin Phoenix apparaissent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films dans lesquels Anne Hathaway joue et Leonardo DiCaprio joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les titres des films où Anne Hathaway et Leonardo DiCaprio jouent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pouvez-vous m'indiquer les films avec Anne Hathaway et Leonardo DiCaprio ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je souhaiterais connaître les titres des films avec Anne Hathaway et Leonardo DiCaprio.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Serait-il possible de voir les films où Anne Hathaway et Leonardo DiCaprio figurent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je voudrais savoir dans quels films apparaissent Anne Hathaway et Leonardo DiCaprio.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Burning Truth Project.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous m'indiquer qui est le réalisateur des films intitulés The Burning Truth Project ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Auriez-vous l'amabilité de me donner le nom du réalisateur des films appelés The Burning Truth Project ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je souhaiterais savoir qui a réalisé les films intitulés The Burning Truth Project.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me dire qui est le réalisateur des films The Burning Truth Project ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je veux connaître le nom du réalisateur pour le film intitulé The Burning Truth Project.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Golden Echo Story.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire qui est le réalisateur des films intitulés The Golden Echo Story ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je souhaite connaître le nom du réalisateur des films appelés The Golden Echo Story.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu m'indiquer qui est le réalisateur des films ayant pour titre The Golden Echo Story ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir qui est le réalisateur des films intitulés The Golden Echo Story.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : S'il vous plaît, montrez-moi le réalisateur des films dont le titre est The Golden Echo Story.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer les titres des films dans lesquels Morgan Freeman joue et qui sont de genre Action.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les titres des films où Morgan Freeman apparaît et qui sont classés comme Action ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais connaître les films avec Morgan Freeman qui appartiennent au genre Action, s'il vous plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourrais-je avoir les titres des films d'action avec Morgan Freeman ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Montrez-moi les films d'action dans lesquels Morgan Freeman joue, s'il vous plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Quels sont les titres des films d'action avec Morgan Freeman ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Chris Hemsworth joue et le genre est Horreur.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Peux-tu me donner les titres des films avec Chris Hemsworth dans le genre Horreur ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films où Chris Hemsworth est acteur et qui sont classés dans le genre Horreur.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourrais-tu m'indiquer les films de Chris Hemsworth qui appartiennent au genre Horreur ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Montre-moi les titres de films dans lesquels Chris Hemsworth joue et qui sont de genre Horreur, s'il te plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je cherche les titres des films de Horreur avec Chris Hemsworth, peux-tu me les fournir ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films dont le réalisateur est Martin Scorsese.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'realisateur'}
#
# ❌ Phrase : Peux-tu me donner les titres des films réalisés par Martin Scorsese ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'realisateur'}
#
# ❌ Phrase : Auriez-vous la gentillesse de me montrer les titres des films de Martin Scorsese ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'realisateur'}
#
# ❌ Phrase : Est-ce que tu pourrais me montrer les titres des films de Martin Scorsese ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'realisateur'}
#
# ❌ Phrase : Je souhaiterais connaître les titres des films réalisés par Martin Scorsese.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'realisateur'}
#
# ❌ Phrase : Pourrais-je avoir les titres des films sous la direction de Martin Scorsese ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'realisateur'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Silent Empire Affair.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pouvez-vous m'indiquer qui est le réalisateur des films intitulés The Silent Empire Affair ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître le nom du réalisateur des films intitulés The Silent Empire Affair.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire qui a réalisé les films intitulés The Silent Empire Affair ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je souhaiterais savoir qui est le directeur des films qui portent le titre The Silent Empire Affair.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Merci de me communiquer le réalisateur des films connus sous le titre The Silent Empire Affair.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Mark Ruffalo et Brad Pitt jouent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me donner les titres des films dans lesquels jouent Mark Ruffalo et Brad Pitt ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les films où Mark Ruffalo et Brad Pitt apparaissent, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films avec Mark Ruffalo et Brad Pitt, merci.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Peux-tu me dire quels films mettent en scène Mark Ruffalo et Brad Pitt ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je souhaiterais voir la liste des films avec Mark Ruffalo et Brad Pitt.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films dans lesquels Morgan Freeman joue et Robert De Niro joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me donner les titres des films avec Morgan Freeman et Robert De Niro ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les films où Morgan Freeman et Robert De Niro apparaissent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films qui présentent Morgan Freeman et Robert De Niro.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Merci de me communiquer les films avec Morgan Freeman et Robert De Niro.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Quels sont les titres des films qui mettent en vedette Morgan Freeman et Robert De Niro ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer les acteurs des films où l'année est 2022.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Montrez-moi s'il vous plaît les acteurs des films de l'année 2022.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Pourriez-vous me donner les noms des acteurs des films de 2022 ?
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : J'aimerais voir qui sont les acteurs des films sortis en 2022.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Pouvez-vous afficher les acteurs des films de 2022 ?
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Je voudrais connaître les acteurs des films de l'année 2022.
# Attendu : {'acteur', 'annee'}
# Extrait : {'annee'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Joaquin Phoenix joue et le genre est Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Montrez-moi s'il vous plaît les titres des films où Joaquin Phoenix est acteur dans le genre Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous m'indiquer les titres des films avec Joaquin Phoenix dans le genre Romance ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je voudrais connaître les titres des films de Joaquin Phoenix qui appartiennent au genre Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Auriez-vous la gentillesse de me donner les titres des films de Joaquin Phoenix dont le genre est la Romance ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Peut-on voir les titres des films romantiques avec Joaquin Phoenix ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Charlize Theron joue et le genre est Thriller.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous me donner les titres des films de Charlize Theron qui sont des thrillers ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais savoir quels sont les films avec Charlize Theron dans le genre thriller.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Peux-tu me montrer les titres des films dans lesquels Charlize Theron joue et qui appartiennent au genre thriller ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Indiquez-moi les films de Charlize Theron qui sont classés en tant que thrillers, s'il vous plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Quels sont les titres de films de Charlize Theron qui entrent dans la catégorie thriller ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Robert De Niro joue et où Keanu Reeves joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me donner les titres des films avec Robert De Niro et Keanu Reeves ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je voudrais savoir quels films mettent en vedette Robert De Niro et Keanu Reeves.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi le titre des films où Robert De Niro et Keanu Reeves apparaissent.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Est-ce que vous pouvez m'indiquer les films dans lesquels Robert De Niro et Keanu Reeves jouent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous s'il vous plaît me préciser les films avec Robert De Niro et Keanu Reeves ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le directeur des films dont le titre est The Golden Promise Affair.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire qui est le réalisateur du film intitulé The Golden Promise Affair ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir qui dirige le film The Golden Promise Affair.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me montrer qui est le réalisateur des films intitulés The Golden Promise Affair ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Qui est le directeur du film The Golden Promise Affair, s'il vous plaît ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Avez-vous des informations sur le réalisateur du film The Golden Promise Affair ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer les titres des films où Mark Ruffalo joue et le genre est Animation.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous me donner les titres des films avec Mark Ruffalo dans le genre Animation ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films d'animation dans lesquels Mark Ruffalo apparaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Merci de m'indiquer les films d'animation où Mark Ruffalo fait partie du casting.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pouvez-vous me dire quels films d'animation incluent Mark Ruffalo ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je souhaiterais obtenir la liste des films animés avec Mark Ruffalo.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Last Dream Project.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous m'indiquer qui est le directeur du film intitulé The Last Dream Project ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir qui réalise le film intitulé The Last Dream Project.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me dire qui est le réalisateur des films qui portent le titre The Last Dream Project ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que quelqu'un peut me dire qui est le réalisateur de The Last Dream Project ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : S'il vous plaît, donnez-moi le nom du réalisateur pour le film intitulé The Last Dream Project.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ...
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Serait-il possible de voir les titres des films de Drame avec Scarlett Johansson ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je cherche les films dans le genre Drame où Scarlett Johansson apparaît. Pouvez-vous m'aider ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Ryan Gosling joue et le genre est Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je voudrais connaître les titres des films avec Ryan Gosling dans le genre Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pourriez-vous m'indiquer les films de Ryan Gosling qui sont classés dans la catégorie Romance ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Montrez-moi les films où l'on peut voir Ryan Gosling et qui sont de type Romance, s'il vous plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je cherche des titres de films de Ryan Gosling qui sont des romances. Pourriez-vous m'aider ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Quels sont les films de Ryan Gosling dans le genre de la Romance ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer l'année des films dont le titre est The Hidden Secret Project.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me dire l'année des films intitulés The Hidden Secret Project ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourrais-je connaître l'année des films qui portent le titre The Hidden Secret Project ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que tu peux me montrer l'année des films qui s'appellent The Hidden Secret Project ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Je voudrais savoir quelle est l'année des films intitulés The Hidden Secret Project.
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous m'indiquer l'année des films ayant pour titre The Hidden Secret Project ?
# Attendu : {'titre', 'annee'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer les titres des films dans lesquels Chris Hemsworth joue et Leonardo DiCaprio joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les titres des films où jouent Chris Hemsworth et Leonardo DiCaprio ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les films avec Chris Hemsworth et Leonardo DiCaprio, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je voudrais connaître les titres des films avec Chris Hemsworth et Leonardo DiCaprio.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me montrer les films dans lesquels Chris Hemsworth et Leonardo DiCaprio sont acteurs ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Serait-il possible de voir les titres des films où Chris Hemsworth et Leonardo DiCaprio apparaissent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Tom Cruise joue et Natalie Portman joue.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Peux-tu me donner les titres des films avec Tom Cruise et Natalie Portman ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous m'indiquer les films dans lesquels Tom Cruise et Natalie Portman apparaissent ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : J'aimerais connaître les titres des films où l'on peut voir Tom Cruise et Natalie Portman.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Montrez-moi les titres des films avec Tom Cruise et Natalie Portman, s'il vous plaît.
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Quels sont les films où Tom Cruise et Natalie Portman sont tous les deux présents ?
# Attendu : {'acteur', 'titre'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Burning Empire Files.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire qui est le réalisateur des films intitulés The Burning Empire Files ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : S'il vous plaît, indiquez-moi le nom du réalisateur pour les films appelés The Burning Empire Files.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Qui est le réalisateur des films qui portent le titre The Burning Empire Files ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais savoir qui réalise les films intitulés The Burning Empire Files.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me montrer le directeur des films sous le titre The Burning Empire Files ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Veuillez me montrer le titre des films où Brad Pitt joue et dont le genre est la Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Pouvez-vous me donner les titres des films de Brad Pitt dans le genre Romance ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Montrez-moi les films avec Brad Pitt qui appartiennent au genre Romance, s'il vous plaît.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Je voudrais connaître les titres des films romantiques où Brad Pitt est présent.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Pourriez-vous me montrer les titres des films romantiques avec Brad Pitt ?
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'acteur'}
#
# ❌ Phrase : Je cherche des films de Brad Pitt qui sont classés comme de la Romance.
# Attendu : {'genre', 'titre', 'acteur'}
# Extrait : {'genre', 'acteur'}
#
# ❌ Phrase : Veuillez me montrer le directeur des films dont le titre est The Golden Dream Files.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Pourriez-vous me dire qui est le réalisateur des films intitulés The Golden Dream Files ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Peux-tu me montrer qui a réalisé les films appelés The Golden Dream Files ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : J'aimerais connaître le nom du réalisateur des films dont le titre est The Golden Dream Files.
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Est-ce que vous pouvez m'indiquer qui est le réalisateur de The Golden Dream Files ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
# ❌ Phrase : Qui est le directeur des films intitulés The Golden Dream Files, s'il vous plaît ?
# Attendu : {'titre', 'realisateur'}
# Extrait : {'titre'}
#
#
# ✅ Précision concept/valeurs : 1254/6762 = 18.54%
#
# 🧠 Évaluation 2 : Intention SELECT et WHERE
#
# ❌ WHERE - Serait-il possible d'obtenir la liste des films des frères Coen ?
# Gold : realisateur = '<val>'; | Pred : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>';
# ❌ WHERE - Pourriez-vous s'il vous plaît me fournir la liste des films dans lesquels Tom Cruise est en vedette aux côtés de Scarlett Johansson ?
# Gold : ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>')) and ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>')); | Pred : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>';
# ❌ SELECT - Pouvez-vous me dire quand les films intitulés The Golden Promise Story sont sortis ?
# Gold : annee | Pred : realisateur
# ❌ SELECT - Veuillez me montrer le directeur et le nombre total de films, groupés par réalisateur, triés par ordre décroissant.
# Gold : realisateur, count(*) as total | Pred : titre
# ❌ WHERE - Veuillez me montrer le directeur et le nombre total de films, groupés par réalisateur, triés par ordre décroissant.
# Gold : NONE | Pred : realisateur = '<val>';
# ❌ SELECT - Pourriez-vous me montrer qui est le réalisateur et combien de films il a réalisés, classés par ordre décroissant ?
# Gold : realisateur, count(*) as total | Pred : titre
# ❌ WHERE - Pourriez-vous me montrer qui est le réalisateur et combien de films il a réalisés, classés par ordre décroissant ?
# Gold : NONE | Pred : realisateur = '<val>';
# ❌ SELECT - Montrez-moi les réalisateurs et le nombre total de leurs films, en les triant par ordre décroissant.
# Gold : realisateur, count(*) as total | Pred : titre
# ❌ WHERE - Montrez-moi les réalisateurs et le nombre total de leurs films, en les triant par ordre décroissant.
# Gold : NONE | Pred : titre like '<val>' order by annee desc;
# ❌ SELECT - Merci de me fournir la liste des réalisateurs et le nombre total de films associés, triés par nombre décroissant.
# Gold : realisateur, count(*) as total | Pred : titre
# ❌ WHERE - Merci de me fournir la liste des réalisateurs et le nombre total de films associés, triés par nombre décroissant.
# Gold : NONE | Pred : ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>')) and ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>'));
# ❌ SELECT - J'aimerais savoir qui sont les réalisateurs et le total de films qu'ils ont dirigés, dans un classement décroissant.
# Gold : realisateur, count(*) as total | Pred : titre
# ❌ WHERE - J'aimerais savoir qui sont les réalisateurs et le total de films qu'ils ont dirigés, dans un classement décroissant.
# Gold : NONE | Pred : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>';
# ❌ SELECT - Peut-on avoir les directeurs avec leur total de films, présentés par ordre décroissant ?
# Gold : realisateur, count(*) as total | Pred : *
# ❌ WHERE - Peut-on avoir les directeurs avec leur total de films, présentés par ordre décroissant ?
# Gold : NONE | Pred : titre like '<val>' order by annee desc;
# ❌ SELECT - Combien d'années ont passé depuis la sortie des films intitulés The Broken Shadow Game ?
# Gold : annee | Pred : realisateur
# ❌ SELECT - Avez-vous des informations sur les films d'Horreur avec Brad Pitt ?
# Gold : titre | Pred : *
# ❌ WHERE - Avez-vous des informations sur les films d'Horreur avec Brad Pitt ?
# Gold : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>'; | Pred : annee between <annee> and <annee>;
# ❌ WHERE - Pourriez-vous m'indiquer les titres de films d'Horreur que Sandra Bullock a réalisés ?
# Gold : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>'; | Pred : realisateur = '<val>';
# ❌ WHERE - J'aimerais connaître les titres des films où joue Tom Hanks avec Hugh Jackman.
# Gold : ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>')) and ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>')); | Pred : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>';
# ❌ SELECT - Veuillez me montrer le genre et le nombre total de films, regroupés par genre triés par ordre décroissant.
# Gold : genre, count(*) as nb | Pred : titre
# ❌ WHERE - Veuillez me montrer le genre et le nombre total de films, regroupés par genre triés par ordre décroissant.
# Gold : NONE | Pred : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>';
# ❌ SELECT - Pourriez-vous m'indiquer les genres ainsi que le nombre total de films, classés par genre de manière décroissante ?
# Gold : genre, count(*) as nb | Pred : titre
# ❌ WHERE - Pourriez-vous m'indiquer les genres ainsi que le nombre total de films, classés par genre de manière décroissante ?
# Gold : NONE | Pred : realisateur = '<val>';
# ❌ SELECT - Serait-il possible de voir les genres et le total des films, organisés par genre dans l'ordre descendent ?
# Gold : genre, count(*) as nb | Pred : titre
# ❌ WHERE - Serait-il possible de voir les genres et le total des films, organisés par genre dans l'ordre descendent ?
# Gold : NONE | Pred : titre like '<val>' order by annee desc;
# ❌ SELECT - Montrez-moi les genres et le total de films, regroupés et triés par genre en ordre décroissant, s'il vous plaît.
# Gold : genre, count(*) as nb | Pred : titre
# ❌ WHERE - Montrez-moi les genres et le total de films, regroupés et triés par genre en ordre décroissant, s'il vous plaît.
# Gold : NONE | Pred : ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>')) and ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>'));
# ❌ SELECT - Je souhaiterais obtenir les genres et le nombre de films, regroupés par genre et classés de façon décroissante.
# Gold : genre, count(*) as nb | Pred : titre
# ❌ WHERE - Je souhaiterais obtenir les genres et le nombre de films, regroupés par genre et classés de façon décroissante.
# Gold : NONE | Pred : ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>')) and ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>'));
# ❌ SELECT - Pouvons-nous avoir une liste des genres avec le nombre total de films, ordonnée par genre de manière décroissante ?
# Gold : genre, count(*) as nb | Pred : titre
# ❌ WHERE - Pouvons-nous avoir une liste des genres avec le nombre total de films, ordonnée par genre de manière décroissante ?
# Gold : NONE | Pred : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>';
# ❌ SELECT - Quelles sont les années des films intitulés The Lost Echo Files, s'il te plaît ?
# Gold : annee | Pred : realisateur
# ❌ SELECT - Pourriez-vous me montrer les années des films intitulés The Hidden Memory Legacy ?
# Gold : annee | Pred : realisateur
# ❌ WHERE - Pourriez-vous m'indiquer les titres des films où joue Robert De Niro et qui relèvent du Drame ?
# Gold : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>'; | Pred : ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>')) and ((acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>'));
# ❌ SELECT - J'aimerais savoir quand sont sortis les films nommés The Frozen Mission Saga, s'il vous plaît.
# Gold : annee | Pred : realisateur
# ❌ SELECT - Montre-moi les films dont le réalisateur est Denis Villeneuve, s'il te plaît.
# Gold : titre | Pred : realisateur
# ❌ SELECT - Pouvez-vous me donner un aperçu des films allant de 1971 à 1983 ?
# Gold : * | Pred : titre
# ❌ SELECT - Pourriez-vous me dire les années des films intitulés The Golden Shadow Code ?
# Gold : annee | Pred : realisateur
# ❌ WHERE - Est-ce que tu pourrais me montrer les titres des films de Martin Scorsese ?
# Gold : realisateur = '<val>'; | Pred : (acteur1 = '<val>' or acteur2 = '<val>' or acteur3 = '<val>') and genre = '<val>';
# ❌ SELECT - Veuillez me montrer les acteurs des films dont le genre est Horreur.
# Gold : distinct acteur1, acteur2, acteur3 | Pred : acteur1, acteur2, acteur3
# ❌ SELECT - Pouvez-vous me montrer les acteurs des films de genre Horreur ?
# Gold : distinct acteur1, acteur2, acteur3 | Pred : acteur1, acteur2, acteur3
# ❌ SELECT - Je voudrais voir les acteurs des films classés comme Horreur.
# Gold : distinct acteur1, acteur2, acteur3 | Pred : acteur1, acteur2, acteur3
# ❌ SELECT - Pourriez-vous m'indiquer les acteurs des films de Horreur ?
# Gold : distinct acteur1, acteur2, acteur3 | Pred : acteur1, acteur2, acteur3
# ❌ WHERE - Pourriez-vous m'indiquer les acteurs des films de Horreur ?
# Gold : genre = '<val>'; | Pred : annee = <annee>;
# ❌ SELECT - Merci de me fournir les noms des acteurs des films qui appartiennent au genre Horreur.
# Gold : distinct acteur1, acteur2, acteur3 | Pred : acteur1, acteur2, acteur3
# ❌ SELECT - Est-ce que vous pourriez me lister les acteurs des films de Horreur ?
# Gold : distinct acteur1, acteur2, acteur3 | Pred : acteur1, acteur2, acteur3
# ❌ WHERE - Est-ce que vous pourriez me lister les acteurs des films de Horreur ?
# Gold : genre = '<val>'; | Pred : annee = <annee>;
# ❌ SELECT - Je recherche des informations sur les acteurs des films de l'année 2005.
# Gold : acteur1, acteur2, acteur3 | Pred : *
#
# ✅ Précision SELECT : 6734/6762 = 99.59%
# ✅ Précision WHERE  : 6741/6762 = 99.69%

# %%
import json
import pandas as pd
import sqlite3
import re
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Perceptron


with open("queries_french_para.json", encoding="utf-8") as f:
    data_train = json.load(f)

with open("queries_french_para_eval.json", encoding="utf-8") as f:
    data_eval = json.load(f)


def normaliser_sql(chaine):
    chaine = chaine.lower()
    chaine = re.sub(r'\s+', ' ', chaine)
    chaine = re.sub(r'\s*=\s*', '=', chaine)
    chaine = re.sub(r'\s*between\s*', ' between ', chaine)
    chaine = chaine.strip().rstrip(';')
    return chaine


def nettoyer_where(clause):
    clause = re.sub(r"'[^']*'", "'<val>'", clause)
    clause = re.sub(r"\d{4}", "<annee>", clause)
    return clause.lower().strip()

def extraire_labels(sql):
    select = re.search(r'select (.+?) from', sql, re.IGNORECASE)
    where = re.search(r'where (.+)', sql, re.IGNORECASE)
    select_label = select.group(1).strip().lower() if select else "UNKNOWN"
    where_label = nettoyer_where(where.group(1)) if where else "NONE"
    return select_label, where_label


select_X, select_y = [], []
for entry in data_train:
    select_label, _ = extraire_labels(entry["sql"])
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
    for phrase in phrases:
        select_X.append(phrase)
        select_y.append(select_label)

pipeline_select = Pipeline([
    ("vectorizer", CountVectorizer()),
    ("perceptron", Perceptron())
])
pipeline_select.fit(select_X, select_y)


df = pd.read_csv("base_films_500.csv")

valeurs_concepts = {
    'titre': df['titre'].dropna().unique().tolist(),
    'realisateur': df['realisateur'].dropna().unique().tolist(),
    'annee': df['annee'].dropna().astype(str).unique().tolist(),
    'genre': df['genre'].dropna().unique().tolist(),
    'acteur1': df['acteur1'].dropna().unique().tolist(),
    'acteur2': df['acteur2'].dropna().unique().tolist(),
    'acteur3': df['acteur3'].dropna().unique().tolist()
}


def analyse_lexicale(requete, lexique):
    concepts_valeurs = []
    deja_vus = set()
    correspondances = []
    for concept, valeurs in lexique.items():
        for valeur in valeurs:
            if valeur.lower() in requete.lower():
                match = re.search(re.escape(valeur), requete, flags=re.IGNORECASE)
                if match:
                    correspondances.append((match.start(), valeur, concept))
    correspondances.sort()
    for _, valeur, concept in correspondances:
        if valeur.lower() not in deja_vus:
            deja_vus.add(valeur.lower())
            concept_label = "acteur" if concept.startswith("acteur") else concept
            concepts_valeurs.append((concept_label, valeur))
    return concepts_valeurs


def generer_where_sql(concepts_valeurs):
    clauses = []
    annees = []

    for concept, valeur in concepts_valeurs:
        if concept == "annee":
            annees.append(valeur)
        elif concept == "acteur":
            clause = f"((acteur1 = '{valeur}' or acteur2 = '{valeur}' or acteur3 = '{valeur}'))"
            clauses.append(clause)
        else:
            clause = f"{concept} = '{valeur}'"
            clauses.append(clause)

    if len(annees) == 2:
        an1, an2 = sorted(annees)
        clauses = [c for c in clauses if not c.startswith("annee")]
        clauses.append(f"annee between {an1} and {an2}")
    elif len(annees) == 1:
        clauses = [c for c in clauses if not c.startswith("annee")]
        clauses.append(f"annee = {annees[0]}")

    return " AND ".join(clauses)


total = 0
correct = 0

for entry in data_eval:
    expected_sql = normaliser_sql(entry["sql"])
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]

    for phrase in phrases:
        total += 1
        concepts_valeurs = analyse_lexicale(phrase, valeurs_concepts)
        select_pred = pipeline_select.predict([phrase])[0]
        where_clause = generer_where_sql(concepts_valeurs)
        sql_gen = f"SELECT {select_pred} FROM films WHERE {where_clause};"
        sql_gen_norm = normaliser_sql(sql_gen)

        print("\n📝 Phrase :", phrase)
        print("✅ Générée :", sql_gen)
        print("🎯 Attendue :", entry["sql"])

        if sql_gen_norm == expected_sql:
            correct += 1
            print("✔️ CORRECT")
        else:
            print("❌ INCORRECT")


print(f"\n✅ Évaluation terminée : {correct} / {total} corrects")
print(f"🎯 Précision : {correct / total * 100:.2f}%")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Anne Hathaway' OR acteur2 = 'Anne Hathaway' OR acteur3 = 'Anne Hathaway') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous me montrer les films d'Anne Hathaway classés dans le genre Drame ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Anne Hathaway' or acteur2 = 'Anne Hathaway' or acteur3 = 'Anne Hathaway')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Anne Hathaway' OR acteur2 = 'Anne Hathaway' OR acteur3 = 'Anne Hathaway') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais connaître les titres des films d'Anne Hathaway qui sont des Drames, s'il vous plaît.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Anne Hathaway' or acteur2 = 'Anne Hathaway' or acteur3 = 'Anne Hathaway')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Anne Hathaway' OR acteur2 = 'Anne Hathaway' OR acteur3 = 'Anne Hathaway') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Auriez-vous la gentillesse de me révéler les titres des films d'Anne Hathaway dans la catégorie Drame ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Anne Hathaway' or acteur2 = 'Anne Hathaway' or acteur3 = 'Anne Hathaway')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Anne Hathaway' OR acteur2 = 'Anne Hathaway' OR acteur3 = 'Anne Hathaway') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer toutes les informations des films où l'année est entre 1973 et 2002.
# ✅ Générée : SELECT * FROM films WHERE annee = 2002;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1973 AND 2002;
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi toutes les infos sur les films dont l'année est comprise entre 1973 et 2002.
# ✅ Générée : SELECT * FROM films WHERE annee = 2002;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1973 AND 2002;
# ❌ INCORRECT
#
# 📝 Phrase : Je voudrais voir toutes les informations des films sortis entre 1973 et 2002.
# ✅ Générée : SELECT * FROM films WHERE annee = 2002;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1973 AND 2002;
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous me fournir toutes les données des films qui ont été réalisés entre 1973 et 2002 ?
# ✅ Générée : SELECT * FROM films WHERE annee = 2002;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1973 AND 2002;
# ❌ INCORRECT
#
# 📝 Phrase : S'il vous plaît, pouvez-vous afficher toutes les informations concernant les films dont l'année se situe entre 1973 et 2002 ?
# ✅ Générée : SELECT * FROM films WHERE annee = 2002;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1973 AND 2002;
# ❌ INCORRECT
#
# 📝 Phrase : Je souhaite obtenir toutes les infos sur les films datant de 1973 à 2002.
# ✅ Générée : SELECT * FROM films WHERE annee = 2002;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1973 AND 2002;
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer le titre des films où Scarlett Johansson joue et Morgan Freeman joue.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' or acteur2 = 'Morgan Freeman' or acteur3 = 'Morgan Freeman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' OR acteur2 = 'Morgan Freeman' OR acteur3 = 'Morgan Freeman'));
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me donner les titres des films avec Scarlett Johansson et Morgan Freeman ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' or acteur2 = 'Morgan Freeman' or acteur3 = 'Morgan Freeman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' OR acteur2 = 'Morgan Freeman' OR acteur3 = 'Morgan Freeman'));
# ✔️ CORRECT
#
# 📝 Phrase : Je souhaiterais connaître les films dans lesquels Scarlett Johansson et Morgan Freeman apparaissent.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' or acteur2 = 'Morgan Freeman' or acteur3 = 'Morgan Freeman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' OR acteur2 = 'Morgan Freeman' OR acteur3 = 'Morgan Freeman'));
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous m'indiquer les titres des films mettant en scène Scarlett Johansson et Morgan Freeman ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' or acteur2 = 'Morgan Freeman' or acteur3 = 'Morgan Freeman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' OR acteur2 = 'Morgan Freeman' OR acteur3 = 'Morgan Freeman'));
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais savoir quels films présentent Scarlett Johansson et Morgan Freeman.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' or acteur2 = 'Morgan Freeman' or acteur3 = 'Morgan Freeman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' OR acteur2 = 'Morgan Freeman' OR acteur3 = 'Morgan Freeman'));
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi s'il vous plaît les titres des films où on retrouve Scarlett Johansson et Morgan Freeman.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' or acteur2 = 'Morgan Freeman' or acteur3 = 'Morgan Freeman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson')) AND ((acteur1 = 'Morgan Freeman' OR acteur2 = 'Morgan Freeman' OR acteur3 = 'Morgan Freeman'));
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le titre des films où le réalisateur est Tim Burton.
# ✅ Générée : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# 🎯 Attendue : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi les titres des films réalisés par Tim Burton.
# ✅ Générée : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# 🎯 Attendue : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me donner les titres des films de Tim Burton ?
# ✅ Générée : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# 🎯 Attendue : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais voir les titres des œuvres de Tim Burton.
# ✅ Générée : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# 🎯 Attendue : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# ✔️ CORRECT
#
# 📝 Phrase : Est-ce que vous pouvez me dire quels films Tim Burton a réalisés ?
# ✅ Générée : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# 🎯 Attendue : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# ✔️ CORRECT
#
# 📝 Phrase : Avez-vous la liste des films réalisés par Tim Burton ?
# ✅ Générée : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# 🎯 Attendue : SELECT titre FROM films WHERE realisateur = 'Tim Burton';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le titre des films où Ryan Gosling joue et dont le genre est Thriller.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Thriller';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Thriller';
# ❌ INCORRECT
#
# 📝 Phrase : Peux-tu me donner les titres des films avec Ryan Gosling classés dans le genre Thriller ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Thriller';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Thriller';
# ❌ INCORRECT
#
# 📝 Phrase : Merci de m'indiquer les titres des films avec Ryan Gosling qui sont des Thrillers.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Thriller';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Thriller';
# ❌ INCORRECT
#
# 📝 Phrase : Pourrais-tu me montrer les films où Ryan Gosling joue et qui sont des Thrillers ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Thriller';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Thriller';
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais connaître les titres des films dans lesquels Ryan Gosling joue et qui appartiennent au genre Thriller.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Thriller';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Thriller';
# ❌ INCORRECT
#
# 📝 Phrase : Aurais-tu la gentillesse de me montrer les films de Ryan Gosling, en particulier ceux de genre Thriller ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Thriller';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Thriller';
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer toutes les informations des films dont le titre contient 'Dark', triées par année en ordre décroissant.
# ✅ Générée : SELECT * FROM films WHERE ;
# 🎯 Attendue : SELECT * FROM films WHERE titre LIKE 'Dark%' ORDER BY annee DESC;
# ❌ INCORRECT
#
# 📝 Phrase : Pouvez-vous m'afficher toutes les infos sur les films avec 'Dark' dans le titre, classées par année décroissante ?
# ✅ Générée : SELECT * FROM films WHERE ;
# 🎯 Attendue : SELECT * FROM films WHERE titre LIKE 'Dark%' ORDER BY annee DESC;
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi toutes les informations des films ayant 'Dark' dans leur titre, organisés par année de la plus récente à la plus ancienne.
# ✅ Générée : SELECT * FROM films WHERE ;
# 🎯 Attendue : SELECT * FROM films WHERE titre LIKE 'Dark%' ORDER BY annee DESC;
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais voir toutes les infos des films qui ont 'Dark' dans le titre, triées de la plus récente à la plus ancienne.
# ✅ Générée : SELECT * FROM films WHERE ;
# 🎯 Attendue : SELECT * FROM films WHERE titre LIKE 'Dark%' ORDER BY annee DESC;
# ❌ INCORRECT
#
# 📝 Phrase : Serait-il possible d'obtenir toutes les informations des films dont le titre inclut 'Dark', classées par année en ordre décroissant ?
# ✅ Générée : SELECT * FROM films WHERE ;
# 🎯 Attendue : SELECT * FROM films WHERE titre LIKE 'Dark%' ORDER BY annee DESC;
# ❌ INCORRECT
#
# 📝 Phrase : Je voudrais consulter toutes les données sur les films contenant 'Dark' dans leur titre, triées des plus récentes aux plus anciennes.
# ✅ Générée : SELECT * FROM films WHERE ;
# 🎯 Attendue : SELECT * FROM films WHERE titre LIKE 'Dark%' ORDER BY annee DESC;
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer toutes les informations des films où l'année est entre 2004 et 2015.
# ✅ Générée : SELECT * FROM films WHERE annee between 2004 and 2015;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2004 AND 2015;
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi toutes les informations sur les films sortis entre 2004 et 2015, s'il vous plaît.
# ✅ Générée : SELECT * FROM films WHERE annee between 2004 and 2015;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2004 AND 2015;
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me fournir toutes les données concernant les films de 2004 à 2015 ?
# ✅ Générée : SELECT * FROM films WHERE annee between 2004 and 2015;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2004 AND 2015;
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais voir toutes les informations des films ayant été produits entre 2004 et 2015.
# ✅ Générée : SELECT * FROM films WHERE annee between 2004 and 2015;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2004 AND 2015;
# ✔️ CORRECT
#
# 📝 Phrase : Merci de m'afficher toutes les infos sur les films qui sont sortis entre 2004 et 2015.
# ✅ Générée : SELECT * FROM films WHERE annee between 2004 and 2015;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2004 AND 2015;
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu me donner toutes les informations des films de l'année 2004 à 2015 ?
# ✅ Générée : SELECT * FROM films WHERE annee between 2004 and 2015;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2004 AND 2015;
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer l'année des films dont le titre est The Dark Echo Legacy.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous me dire l'année des films intitulés The Dark Echo Legacy ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais connaître l'année des films appelés The Dark Echo Legacy.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Est-ce que vous pourriez me fournir l'année des films ayant pour titre The Dark Echo Legacy ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Serait-il possible d'obtenir l'année des films portant le nom The Dark Echo Legacy ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi, s'il vous plaît, l'année des films qui s'appellent The Dark Echo Legacy.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer toutes les informations des films dont l'année est comprise entre 1978 et 1991.
# ✅ Générée : SELECT * FROM films WHERE annee = 1991;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1978 AND 1991;
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi toutes les infos sur les films sortis entre 1978 et 1991.
# ✅ Générée : SELECT * FROM films WHERE annee = 1991;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1978 AND 1991;
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous me fournir les détails des films de 1978 à 1991 ?
# ✅ Générée : SELECT * FROM films WHERE annee = 1991;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1978 AND 1991;
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais obtenir toutes les informations concernant les films de 1978 à 1991.
# ✅ Générée : SELECT * FROM films WHERE annee = 1991;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1978 AND 1991;
# ❌ INCORRECT
#
# 📝 Phrase : Merci de me donner les données des films qui sont sortis entre 1978 et 1991.
# ✅ Générée : SELECT * FROM films WHERE annee = 1991;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1978 AND 1991;
# ❌ INCORRECT
#
# 📝 Phrase : Je souhaiterais connaître les films sortis entre 1978 et 1991, pouvez-vous me montrer les informations ?
# ✅ Générée : SELECT * FROM films WHERE annee = 1991;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1978 AND 1991;
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer l'année des films intitulés The Lost Truth Files.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu me dire l'année des films qui s'appellent The Lost Truth Files ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# ✔️ CORRECT
#
# 📝 Phrase : Pourrais-je avoir l'année des films ayant pour titre The Lost Truth Files ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# ✔️ CORRECT
#
# 📝 Phrase : Merci de m'indiquer l'année des films intitulés The Lost Truth Files.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais connaître l'année des films intitulés The Lost Truth Files.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# ✔️ CORRECT
#
# 📝 Phrase : Serait-il possible d'obtenir l'année des films intitulés The Lost Truth Files ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Lost Truth Files';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Burning Journey Code.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous me dire qui est le réalisateur des films intitulés The Burning Journey Code ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais connaître le nom du réalisateur des films qui s'appellent The Burning Journey Code.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me fournir le nom du directeur des films appelés The Burning Journey Code ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# ✔️ CORRECT
#
# 📝 Phrase : Serait-il possible de savoir qui a réalisé les films dont le titre est The Burning Journey Code ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous m'indiquer le réalisateur des films intitulés The Burning Journey Code ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Journey Code';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer toutes les informations des films où l'année est comprise entre 1966 et 1994.
# ✅ Générée : SELECT * FROM films WHERE annee = 1994;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1966 AND 1994;
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi toutes les données des films sortis entre 1966 et 1994.
# ✅ Générée : SELECT * FROM films WHERE annee = 1994;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1966 AND 1994;
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous afficher les informations relatives aux films de 1966 à 1994 ?
# ✅ Générée : SELECT * FROM films WHERE annee = 1994;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1966 AND 1994;
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais voir toutes les informations concernant les films dont l'année est entre 1966 et 1994.
# ✅ Générée : SELECT * FROM films WHERE annee = 1994;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1966 AND 1994;
# ❌ INCORRECT
#
# 📝 Phrase : Pouvez-vous s'il vous plaît me fournir les détails des films de la période 1966 à 1994 ?
# ✅ Générée : SELECT * FROM films WHERE annee = 1994;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1966 AND 1994;
# ❌ INCORRECT
#
# 📝 Phrase : Merci de montrer toutes les infos sur les films ayant été réalisés entre 1966 et 1994.
# ✅ Générée : SELECT * FROM films WHERE annee = 1994;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 1966 AND 1994;
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer les titres des films où Johnny Depp joue et Scarlett Johansson joue.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' or acteur2 = 'Johnny Depp' or acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' OR acteur2 = 'Johnny Depp' OR acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson'));
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous me montrer les titres des films avec Johnny Depp et Scarlett Johansson ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' or acteur2 = 'Johnny Depp' or acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' OR acteur2 = 'Johnny Depp' OR acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson'));
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me donner les titres des films dans lesquels jouent Johnny Depp et Scarlett Johansson ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' or acteur2 = 'Johnny Depp' or acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' OR acteur2 = 'Johnny Depp' OR acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson'));
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais savoir quels films ont Johnny Depp et Scarlett Johansson au casting.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' or acteur2 = 'Johnny Depp' or acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' OR acteur2 = 'Johnny Depp' OR acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson'));
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous m'indiquer les titres des films avec Johnny Depp et Scarlett Johansson ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' or acteur2 = 'Johnny Depp' or acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' OR acteur2 = 'Johnny Depp' OR acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson'));
# ✔️ CORRECT
#
# 📝 Phrase : Je cherche les titres des films où Johnny Depp et Scarlett Johansson apparaissent.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' or acteur2 = 'Johnny Depp' or acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' or acteur2 = 'Scarlett Johansson' or acteur3 = 'Scarlett Johansson'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Johnny Depp' OR acteur2 = 'Johnny Depp' OR acteur3 = 'Johnny Depp')) AND ((acteur1 = 'Scarlett Johansson' OR acteur2 = 'Scarlett Johansson' OR acteur3 = 'Scarlett Johansson'));
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer toutes les informations des films dont l'année est comprise entre 2016 et 2019.
# ✅ Générée : SELECT * FROM films WHERE annee between 2016 and 2019;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2016 AND 2019;
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi toutes les infos des films qui sortent entre 2016 et 2019.
# ✅ Générée : SELECT * FROM films WHERE annee between 2016 and 2019;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2016 AND 2019;
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous m'afficher toutes les informations concernant les films sortis entre 2016 et 2019 ?
# ✅ Générée : SELECT * FROM films WHERE annee between 2016 and 2019;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2016 AND 2019;
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais voir toutes les infos sur les films ayant été réalisés entre 2016 et 2019.
# ✅ Générée : SELECT * FROM films WHERE annee between 2016 and 2019;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2016 AND 2019;
# ✔️ CORRECT
#
# 📝 Phrase : Merci de me fournir toutes les informations sur les films de l'année 2016 à 2019.
# ✅ Générée : SELECT * FROM films WHERE annee between 2016 and 2019;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2016 AND 2019;
# ✔️ CORRECT
#
# 📝 Phrase : Je souhaite obtenir les détails sur les films sortis entre 2016 et 2019.
# ✅ Générée : SELECT * FROM films WHERE annee between 2016 and 2019;
# 🎯 Attendue : SELECT * FROM films WHERE annee BETWEEN 2016 AND 2019;
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer les titres des films où Natalie Portman joue et dont le genre est Drame.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi s'il vous plaît les titres des films dans lesquels Natalie Portman joue et qui sont des Drames.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous m'indiquer les titres des films avec Natalie Portman, de genre Drame ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais savoir quels sont les films avec Natalie Portman qui appartiennent au genre Drame.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Pouvez-vous me donner les titres des films de Drame avec Natalie Portman ?
# ✅ Générée : SELECT titre FROM films WHERE genre = 'Drame' AND ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman'));
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Je cherche les films où Natalie Portman apparaît et qui sont dans le genre Drame, pourriez-vous m'aider ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer l'année des films dont le titre est The Infinite Memory Files.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous m'indiquer l'année des films intitulés The Infinite Memory Files ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais savoir quelle est l'année des films qui portent le titre The Infinite Memory Files.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous me donner l'année des films qui s'appellent The Infinite Memory Files ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# ✔️ CORRECT
#
# 📝 Phrase : Est-ce que vous avez l'année des films intitulés The Infinite Memory Files ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais connaître l'année de sortie des films ayant pour titre The Infinite Memory Files.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Infinite Memory Files';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer l'année des films dont le titre est The Dark Echo Saga.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi l'année des films intitulés The Dark Echo Saga, s'il vous plaît.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous indiquer l'année des films qui portent le titre The Dark Echo Saga ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais connaître l'année des films appelés The Dark Echo Saga.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu me dire quelle année les films The Dark Echo Saga ont été réalisés ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# ✔️ CORRECT
#
# 📝 Phrase : Dis-moi, quelle est l'année des films intitulés The Dark Echo Saga ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Dark Echo Saga';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le titre des films où Sandra Bullock joue et dont le genre est Drame.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous me donner les titres des films avec Sandra Bullock qui sont des Drames ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais connaître les titres des films dans lesquels Sandra Bullock joue et qui appartiennent au genre Drame.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi les films avec Sandra Bullock classés comme Drame, s'il vous plaît.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous me lister les films où Sandra Bullock apparaît et qui sont catégorisés comme Drame ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Je cherche les titres des films de Sandra Bullock dans le genre Drame, merci.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Drame';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Drame';
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer le titre des films où Charlize Theron joue et le genre est la science-fiction.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Charlize Theron' or acteur2 = 'Charlize Theron' or acteur3 = 'Charlize Theron')) AND genre = 'Science-fiction';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Charlize Theron' OR acteur2 = 'Charlize Theron' OR acteur3 = 'Charlize Theron') AND genre = 'Science-fiction';
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous me donner les titres des films avec Charlize Theron dans le genre science-fiction ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Charlize Theron' or acteur2 = 'Charlize Theron' or acteur3 = 'Charlize Theron')) AND genre = 'Science-fiction';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Charlize Theron' OR acteur2 = 'Charlize Theron' OR acteur3 = 'Charlize Theron') AND genre = 'Science-fiction';
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi s'il vous plaît les films de Charlize Theron qui sont classés en science-fiction.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Charlize Theron' or acteur2 = 'Charlize Theron' or acteur3 = 'Charlize Theron')) AND genre = 'Science-fiction';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Charlize Theron' OR acteur2 = 'Charlize Theron' OR acteur3 = 'Charlize Theron') AND genre = 'Science-fiction';
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais savoir quels films avec Charlize Theron appartiennent au genre science-fiction.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Charlize Theron' or acteur2 = 'Charlize Theron' or acteur3 = 'Charlize Theron')) AND genre = 'Science-fiction';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Charlize Theron' OR acteur2 = 'Charlize Theron' OR acteur3 = 'Charlize Theron') AND genre = 'Science-fiction';
# ❌ INCORRECT
#
# 📝 Phrase : Pouvez-vous afficher les titres des films de Charlize Theron qui relèvent de la science-fiction ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Charlize Theron' or acteur2 = 'Charlize Theron' or acteur3 = 'Charlize Theron')) AND genre = 'Science-fiction';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Charlize Theron' OR acteur2 = 'Charlize Theron' OR acteur3 = 'Charlize Theron') AND genre = 'Science-fiction';
# ❌ INCORRECT
#
# 📝 Phrase : Je voudrais connaître les films où Charlize Theron apparaît dans le domaine de la science-fiction.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Charlize Theron' or acteur2 = 'Charlize Theron' or acteur3 = 'Charlize Theron')) AND genre = 'Science-fiction';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Charlize Theron' OR acteur2 = 'Charlize Theron' OR acteur3 = 'Charlize Theron') AND genre = 'Science-fiction';
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Burning Dream Game.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous m'indiquer qui est le réalisateur des films intitulés The Burning Dream Game ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me dire qui a réalisé le film The Burning Dream Game ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais savoir qui est le directeur des films avec le titre The Burning Dream Game.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# ✔️ CORRECT
#
# 📝 Phrase : Merci de me dire qui est le réalisateur des films nommés The Burning Dream Game.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# ✔️ CORRECT
#
# 📝 Phrase : Qui est le réalisateur des films appelés The Burning Dream Game, s'il vous plaît ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Dream Game';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le titre des films où Sandra Bullock joue et dont le genre est Comédie.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Comédie';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Comédie';
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi les titres des films dans lesquels Sandra Bullock joue et qui sont de genre comédie.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Comédie';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Comédie';
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous me donner les titres des comédies avec Sandra Bullock ?
# ✅ Générée : SELECT titre FROM films WHERE genre = 'Comédie' AND ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock'));
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Comédie';
# ❌ INCORRECT
#
# 📝 Phrase : J'aimerais connaître les films de Sandra Bullock classés dans la catégorie comédie.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock')) AND genre = 'Comédie';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Comédie';
# ❌ INCORRECT
#
# 📝 Phrase : Pouvez-vous me fournir les titres des films comiques avec Sandra Bullock ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock'));
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Comédie';
# ❌ INCORRECT
#
# 📝 Phrase : Je cherche les films de genre comédie dans lesquels Sandra Bullock apparaît.
# ✅ Générée : SELECT titre FROM films WHERE genre = 'Comédie' AND ((acteur1 = 'Sandra Bullock' or acteur2 = 'Sandra Bullock' or acteur3 = 'Sandra Bullock'));
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Sandra Bullock' OR acteur2 = 'Sandra Bullock' OR acteur3 = 'Sandra Bullock') AND genre = 'Comédie';
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer le directeur des films dont le titre est The Frozen Shadow Legacy.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu me dire qui est le réalisateur des films intitulés The Frozen Shadow Legacy ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Pourrais-je savoir qui a réalisé les films portant le titre The Frozen Shadow Legacy ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais connaître le nom du réalisateur des films intitulés The Frozen Shadow Legacy.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : S'il vous plaît, pourriez-vous m'indiquer le réalisateur des films qui s'appellent The Frozen Shadow Legacy ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Qui est le directeur des films intitulés The Frozen Shadow Legacy ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Frozen Shadow Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Broken Echo Legacy.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu m'indiquer le réalisateur des films intitulés The Broken Echo Legacy ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Pourrais-je avoir des informations sur le réalisateur des films The Broken Echo Legacy ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me dire qui est le réalisateur des films dont le titre est The Broken Echo Legacy ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais savoir qui a réalisé les films portant le titre The Broken Echo Legacy.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Qui est le réalisateur des films The Broken Echo Legacy ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Broken Echo Legacy';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer l'année des films dont le titre est The Broken Echo Code.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu me dire quelle année c'est pour le film intitulé The Broken Echo Code ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# ✔️ CORRECT
#
# 📝 Phrase : Pourrais-je avoir l'année des films appelés The Broken Echo Code ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais savoir l'année des films portant le titre The Broken Echo Code.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# ✔️ CORRECT
#
# 📝 Phrase : Salut, pourrais-tu m'indiquer l'année des films qui s'appellent The Broken Echo Code ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# ✔️ CORRECT
#
# 📝 Phrase : Avez-vous l'année des films qui ont pour titre The Broken Echo Code ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Echo Code';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer l'année des films dont le titre est The Broken Secret Chronicles.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous me dire l'année des films intitulés The Broken Secret Chronicles ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous m'indiquer l'année de sortie des films appelés The Broken Secret Chronicles ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais savoir en quelle année sont sortis les films intitulés The Broken Secret Chronicles.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# ✔️ CORRECT
#
# 📝 Phrase : Est-il possible de connaître l'année des films avec le titre The Broken Secret Chronicles ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# ✔️ CORRECT
#
# 📝 Phrase : Merci de me fournir l'année des films portant le nom de The Broken Secret Chronicles.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Broken Secret Chronicles';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Burning Memory Chronicles.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Memory Chronicles';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Memory Chronicles';
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi qui est le réalisateur des films intitulés The Burning Memory Chronicles.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Memory Chronicles';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Memory Chronicles';
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous m'indiquer le réalisateur des films qui s'appellent The Burning Memory Chronicles ?
# ...
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous m'indiquer les films de Ryan Gosling qui sont classés dans la catégorie Romance ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Romance';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi les films où l'on peut voir Ryan Gosling et qui sont de type Romance, s'il vous plaît.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Romance';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Je cherche des titres de films de Ryan Gosling qui sont des romances. Pourriez-vous m'aider ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Romance';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Quels sont les films de Ryan Gosling dans le genre de la Romance ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling')) AND genre = 'Romance';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Ryan Gosling' OR acteur2 = 'Ryan Gosling' OR acteur3 = 'Ryan Gosling') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer l'année des films dont le titre est The Hidden Secret Project.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu me dire l'année des films intitulés The Hidden Secret Project ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# ✔️ CORRECT
#
# 📝 Phrase : Pourrais-je connaître l'année des films qui portent le titre The Hidden Secret Project ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# ✔️ CORRECT
#
# 📝 Phrase : Est-ce que tu peux me montrer l'année des films qui s'appellent The Hidden Secret Project ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais savoir quelle est l'année des films intitulés The Hidden Secret Project.
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous m'indiquer l'année des films ayant pour titre The Hidden Secret Project ?
# ✅ Générée : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# 🎯 Attendue : SELECT annee FROM films WHERE titre = 'The Hidden Secret Project';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer les titres des films dans lesquels Chris Hemsworth joue et Leonardo DiCaprio joue.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' or acteur2 = 'Chris Hemsworth' or acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' or acteur2 = 'Leonardo DiCaprio' or acteur3 = 'Leonardo DiCaprio'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' OR acteur2 = 'Chris Hemsworth' OR acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' OR acteur2 = 'Leonardo DiCaprio' OR acteur3 = 'Leonardo DiCaprio'));
# ✔️ CORRECT
#
# 📝 Phrase : Pouvez-vous me donner les titres des films où jouent Chris Hemsworth et Leonardo DiCaprio ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' or acteur2 = 'Chris Hemsworth' or acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' or acteur2 = 'Leonardo DiCaprio' or acteur3 = 'Leonardo DiCaprio'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' OR acteur2 = 'Chris Hemsworth' OR acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' OR acteur2 = 'Leonardo DiCaprio' OR acteur3 = 'Leonardo DiCaprio'));
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi les films avec Chris Hemsworth et Leonardo DiCaprio, s'il vous plaît.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' or acteur2 = 'Chris Hemsworth' or acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' or acteur2 = 'Leonardo DiCaprio' or acteur3 = 'Leonardo DiCaprio'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' OR acteur2 = 'Chris Hemsworth' OR acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' OR acteur2 = 'Leonardo DiCaprio' OR acteur3 = 'Leonardo DiCaprio'));
# ✔️ CORRECT
#
# 📝 Phrase : Je voudrais connaître les titres des films avec Chris Hemsworth et Leonardo DiCaprio.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' or acteur2 = 'Chris Hemsworth' or acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' or acteur2 = 'Leonardo DiCaprio' or acteur3 = 'Leonardo DiCaprio'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' OR acteur2 = 'Chris Hemsworth' OR acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' OR acteur2 = 'Leonardo DiCaprio' OR acteur3 = 'Leonardo DiCaprio'));
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me montrer les films dans lesquels Chris Hemsworth et Leonardo DiCaprio sont acteurs ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' or acteur2 = 'Chris Hemsworth' or acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' or acteur2 = 'Leonardo DiCaprio' or acteur3 = 'Leonardo DiCaprio'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' OR acteur2 = 'Chris Hemsworth' OR acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' OR acteur2 = 'Leonardo DiCaprio' OR acteur3 = 'Leonardo DiCaprio'));
# ✔️ CORRECT
#
# 📝 Phrase : Serait-il possible de voir les titres des films où Chris Hemsworth et Leonardo DiCaprio apparaissent ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' or acteur2 = 'Chris Hemsworth' or acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' or acteur2 = 'Leonardo DiCaprio' or acteur3 = 'Leonardo DiCaprio'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' OR acteur2 = 'Chris Hemsworth' OR acteur3 = 'Chris Hemsworth')) AND ((acteur1 = 'Leonardo DiCaprio' OR acteur2 = 'Leonardo DiCaprio' OR acteur3 = 'Leonardo DiCaprio'));
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le titre des films où Tom Cruise joue et Natalie Portman joue.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' or acteur2 = 'Tom Cruise' or acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' OR acteur2 = 'Tom Cruise' OR acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman'));
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu me donner les titres des films avec Tom Cruise et Natalie Portman ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' or acteur2 = 'Tom Cruise' or acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' OR acteur2 = 'Tom Cruise' OR acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman'));
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous m'indiquer les films dans lesquels Tom Cruise et Natalie Portman apparaissent ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' or acteur2 = 'Tom Cruise' or acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' OR acteur2 = 'Tom Cruise' OR acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman'));
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais connaître les titres des films où l'on peut voir Tom Cruise et Natalie Portman.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' or acteur2 = 'Tom Cruise' or acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' OR acteur2 = 'Tom Cruise' OR acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman'));
# ✔️ CORRECT
#
# 📝 Phrase : Montrez-moi les titres des films avec Tom Cruise et Natalie Portman, s'il vous plaît.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' or acteur2 = 'Tom Cruise' or acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' OR acteur2 = 'Tom Cruise' OR acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman'));
# ✔️ CORRECT
#
# 📝 Phrase : Quels sont les films où Tom Cruise et Natalie Portman sont tous les deux présents ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' or acteur2 = 'Tom Cruise' or acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman'));
# 🎯 Attendue : SELECT titre FROM films WHERE ((acteur1 = 'Tom Cruise' OR acteur2 = 'Tom Cruise' OR acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Natalie Portman' OR acteur2 = 'Natalie Portman' OR acteur3 = 'Natalie Portman'));
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le réalisateur des films dont le titre est The Burning Empire Files.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me dire qui est le réalisateur des films intitulés The Burning Empire Files ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# ✔️ CORRECT
#
# 📝 Phrase : S'il vous plaît, indiquez-moi le nom du réalisateur pour les films appelés The Burning Empire Files.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# ✔️ CORRECT
#
# 📝 Phrase : Qui est le réalisateur des films qui portent le titre The Burning Empire Files ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais savoir qui réalise les films intitulés The Burning Empire Files.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me montrer le directeur des films sous le titre The Burning Empire Files ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Burning Empire Files';
# ✔️ CORRECT
#
# 📝 Phrase : Veuillez me montrer le titre des films où Brad Pitt joue et dont le genre est la Romance.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt')) AND genre = 'Romance';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Brad Pitt' OR acteur2 = 'Brad Pitt' OR acteur3 = 'Brad Pitt') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Pouvez-vous me donner les titres des films de Brad Pitt dans le genre Romance ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt')) AND genre = 'Romance';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Brad Pitt' OR acteur2 = 'Brad Pitt' OR acteur3 = 'Brad Pitt') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Montrez-moi les films avec Brad Pitt qui appartiennent au genre Romance, s'il vous plaît.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt')) AND genre = 'Romance';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Brad Pitt' OR acteur2 = 'Brad Pitt' OR acteur3 = 'Brad Pitt') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Je voudrais connaître les titres des films romantiques où Brad Pitt est présent.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt'));
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Brad Pitt' OR acteur2 = 'Brad Pitt' OR acteur3 = 'Brad Pitt') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Pourriez-vous me montrer les titres des films romantiques avec Brad Pitt ?
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt'));
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Brad Pitt' OR acteur2 = 'Brad Pitt' OR acteur3 = 'Brad Pitt') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Je cherche des films de Brad Pitt qui sont classés comme de la Romance.
# ✅ Générée : SELECT titre FROM films WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt')) AND genre = 'Romance';
# 🎯 Attendue : SELECT titre FROM films WHERE (acteur1 = 'Brad Pitt' OR acteur2 = 'Brad Pitt' OR acteur3 = 'Brad Pitt') AND genre = 'Romance';
# ❌ INCORRECT
#
# 📝 Phrase : Veuillez me montrer le directeur des films dont le titre est The Golden Dream Files.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# ✔️ CORRECT
#
# 📝 Phrase : Pourriez-vous me dire qui est le réalisateur des films intitulés The Golden Dream Files ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# ✔️ CORRECT
#
# 📝 Phrase : Peux-tu me montrer qui a réalisé les films appelés The Golden Dream Files ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# ✔️ CORRECT
#
# 📝 Phrase : J'aimerais connaître le nom du réalisateur des films dont le titre est The Golden Dream Files.
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# ✔️ CORRECT
#
# 📝 Phrase : Est-ce que vous pouvez m'indiquer qui est le réalisateur de The Golden Dream Files ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# ✔️ CORRECT
#
# 📝 Phrase : Qui est le directeur des films intitulés The Golden Dream Files, s'il vous plaît ?
# ✅ Générée : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# 🎯 Attendue : SELECT realisateur FROM films WHERE titre = 'The Golden Dream Files';
# ✔️ CORRECT
#
# ✅ Évaluation terminée : 4809 / 6762 corrects
# 🎯 Précision : 71.12%

# %%
import json
import pandas as pd
import sqlite3
import re
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Perceptron

# Charger corpus d'entraînement
with open("queries_french_para.json", encoding="utf-8") as f:
    data_train = json.load(f)

# Charger corpus d'évaluation (avec valeurs)
with open("queries_french_para_eval_values.json", encoding="utf-8") as f:
    data_eval = json.load(f)

# Prétraitement du SQL
def extraire_labels(sql):
    select = re.search(r'select (.+?) from', sql, re.IGNORECASE)
    select_label = select.group(1).strip().lower() if select else "UNKNOWN"
    return select_label

# Entraînement modèle SELECT
select_X, select_y = [], []
for entry in data_train:
    select_label = extraire_labels(entry["sql"])
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
    for phrase in phrases:
        select_X.append(phrase)
        select_y.append(select_label)

pipeline_select = Pipeline([
    ("vectorizer", CountVectorizer()),
    ("perceptron", Perceptron())
])
pipeline_select.fit(select_X, select_y)

# Charger la base films
df = pd.read_csv("base_films_500.csv")
conn = sqlite3.connect(":memory:")
df.to_sql("films", conn, index=False, if_exists="replace")

# Création du lexique
valeurs_concepts = {
    'titre': df['titre'].dropna().unique().tolist(),
    'realisateur': df['realisateur'].dropna().unique().tolist(),
    'annee': df['annee'].dropna().astype(str).unique().tolist(),
    'genre': df['genre'].dropna().unique().tolist(),
    'acteur1': df['acteur1'].dropna().unique().tolist(),
    'acteur2': df['acteur2'].dropna().unique().tolist(),
    'acteur3': df['acteur3'].dropna().unique().tolist()
}

# Analyse lexicale
def analyse_lexicale(requete, lexique):
    concepts_valeurs = []
    deja_vus = set()
    correspondances = []
    for concept, valeurs in lexique.items():
        for valeur in valeurs:
            if valeur.lower() in requete.lower():
                match = re.search(re.escape(valeur), requete, flags=re.IGNORECASE)
                if match:
                    correspondances.append((match.start(), valeur, concept))
    correspondances.sort()
    for _, valeur, concept in correspondances:
        if valeur.lower() not in deja_vus:
            deja_vus.add(valeur.lower())
            concept_label = "acteur" if concept.startswith("acteur") else concept
            concepts_valeurs.append((concept_label, valeur))
    return concepts_valeurs

# WHERE avec BETWEEN et double parenthèses
def generer_where_sql(concepts_valeurs):
    clauses = []
    annees = []
    for concept, valeur in concepts_valeurs:
        if concept == "annee":
            annees.append(valeur)
        elif concept == "acteur":
            clause = f"((acteur1 = '{valeur}' or acteur2 = '{valeur}' or acteur3 = '{valeur}'))"
            clauses.append(clause)
        else:
            clause = f"{concept} = '{valeur}'"
            clauses.append(clause)
    if len(annees) == 2:
        an1, an2 = sorted(annees)
        clauses = [c for c in clauses if not c.startswith("annee")]
        clauses.append(f"annee between {an1} and {an2}")
    elif len(annees) == 1:
        clauses = [c for c in clauses if not c.startswith("annee")]
        clauses.append(f"annee = {annees[0]}")
    return " AND ".join(clauses)

# Fonction d'exécution et comparaison
def extraire_reponse(select, where):
    try:
        sql = f"SELECT {select} FROM films WHERE {where};"
        result = pd.read_sql_query(sql, conn)
        if not result.empty:
            val = str(result.iloc[0, 0])
            return val.strip()
        return None
    except:
        return None

# ÉVALUATION
total = 0
correct = 0

for entry in data_eval:
    phrase = entry["query"]
    valeur_attendue = entry["value"].strip()

    concepts_valeurs = analyse_lexicale(phrase, valeurs_concepts)
    select_pred = pipeline_select.predict([phrase])[0]
    where_clause = generer_where_sql(concepts_valeurs)
    valeur_obtenue = extraire_reponse(select_pred, where_clause)

    print("\n🔎 Query :", phrase)
    print("🧠 SQL → SELECT", select_pred, "WHERE", where_clause)
    print("🎯 Attendu :", valeur_attendue)
    print("✅ Obtenu  :", valeur_obtenue)

    total += 1
    if valeur_obtenue and valeur_obtenue.strip().lower() == valeur_attendue.lower():
        correct += 1
        print("✔️ Correct")
    else:
        print("❌ Incorrect")

# Résultat global
print(f"\n📊 Évaluation terminée : {correct} / {total} corrects")
print(f"🎯 Précision : {correct / total * 100:.2f}%")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 🔎 Query : Pourriez-vous m'indiquer qui a réalisé The Infinite Shadow Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Shadow Affair'
# 🎯 Attendu : Bong Joon-ho
# ✅ Obtenu  : Bong Joon-ho
# ✔️ Correct
#
# 🔎 Query : Je souhaiterais savoir qui est le réalisateur du film The Silent Shadow Game.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Shadow Game'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir l'année des films intitulés The Infinite Shadow Affair.
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Shadow Affair'
# 🎯 Attendu : 2011
# ✅ Obtenu  : 2011
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez m'indiquer le réalisateur des films intitulés The Golden Shadow Code ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Shadow Code'
# 🎯 Attendu : James Cameron
# ✅ Obtenu  : James Cameron
# ✔️ Correct
#
# 🔎 Query : Je voudrais connaître le réalisateur des films intitulés The Hidden Echo Chronicles.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Echo Chronicles'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez m'informer sur l'année des films intitulés The Infinite Secret Game ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Secret Game'
# 🎯 Attendu : 2024
# ✅ Obtenu  : 2024
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui dirige les films ayant pour titre The Hidden Mission Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Mission Files'
# 🎯 Attendu : Bong Joon-ho
# ✅ Obtenu  : Bong Joon-ho
# ✔️ Correct
#
# 🔎 Query : Je souhaiterais connaître le réalisateur des films qui portent le titre The Frozen Promise Story.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Promise Story'
# 🎯 Attendu : Robert Zemeckis
# ✅ Obtenu  : Robert Zemeckis
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire qui est le réalisateur des films appelés The Broken Truth Game ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Truth Game'
# 🎯 Attendu : Ridley Scott
# ✅ Obtenu  : Ridley Scott
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me donner l'année des films intitulés The Infinite Journey Game ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Journey Game'
# 🎯 Attendu : 1982
# ✅ Obtenu  : 1982
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez me dire quelle est l'année des films intitulés The Dark Mission Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Mission Files'
# 🎯 Attendu : 2007
# ✅ Obtenu  : 2007
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année des films portant le titre The Dark Echo Code.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Echo Code'
# 🎯 Attendu : 2003
# ✅ Obtenu  : 2003
# ✔️ Correct
#
# 🔎 Query : Merci de m'informer sur l'année des films intitulés The Dark Truth Code.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Truth Code'
# 🎯 Attendu : 1980
# ✅ Obtenu  : 1980
# ✔️ Correct
#
# 🔎 Query : Pourrais-je connaître l'année des films appelés The Dark Echo Protocol ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Echo Protocol'
# 🎯 Attendu : 1987
# ✅ Obtenu  : 1987
# ✔️ Correct
#
# 🔎 Query : Montrez-moi s'il vous plaît les films où Hugh Jackman et Zendaya sont présents.
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Hugh Jackman' or acteur2 = 'Hugh Jackman' or acteur3 = 'Hugh Jackman')) AND ((acteur1 = 'Zendaya' or acteur2 = 'Zendaya' or acteur3 = 'Zendaya'))
# 🎯 Attendu : The Infinite Truth Protocol
# ✅ Obtenu  : The Infinite Truth Protocol
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le directeur des films appelés The Frozen Empire Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Empire Affair'
# 🎯 Attendu : Greta Gerwig
# ✅ Obtenu  : Greta Gerwig
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui a réalisé les films portant le titre The Lost Secret Code ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Secret Code'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire qui est le réalisateur des films appelés The Lost Mission Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Mission Legacy'
# 🎯 Attendu : Quentin Tarantino
# ✅ Obtenu  : Quentin Tarantino
# ✔️ Correct
#
# 🔎 Query : Merci de m'informer sur l'année des films qui ont pour titre The Burning Shadow Story.
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Shadow Story'
# 🎯 Attendu : 1986
# ✅ Obtenu  : 1986
# ✔️ Correct
#
# 🔎 Query : Est-ce que tu sais qui est le réalisateur du film The Lost Promise Code ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Promise Code'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir en quelle année sont sortis les films ayant pour titre The Lost Mission Legacy.
# 🧠 SQL → SELECT annee WHERE titre = 'The Lost Mission Legacy'
# 🎯 Attendu : 1996
# ✅ Obtenu  : 1996
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer qui est le réalisateur des films appelés The Frozen Dream Project ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Dream Project'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : S'il vous plaît, qui est le réalisateur des films intitulés The Lost Dream Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Dream Affair'
# 🎯 Attendu : Francis Ford Coppola
# ✅ Obtenu  : Francis Ford Coppola
# ✔️ Correct
#
# 🔎 Query : Je souhaiterais obtenir la liste des films avec Tom Cruise et Charlize Theron.
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Tom Cruise' or acteur2 = 'Tom Cruise' or acteur3 = 'Tom Cruise')) AND ((acteur1 = 'Charlize Theron' or acteur2 = 'Charlize Theron' or acteur3 = 'Charlize Theron'))
# 🎯 Attendu : The Lost Empire Protocol
# ✅ Obtenu  : The Lost Empire Protocol
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer l'année des films intitulés The Dark Empire Legacy ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Empire Legacy'
# 🎯 Attendu : 2016
# ✅ Obtenu  : 2016
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année de sortie des films intitulés The Frozen Dream Story.
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Dream Story'
# 🎯 Attendu : 2009
# ✅ Obtenu  : 2009
# ✔️ Correct
#
# 🔎 Query : Pourrais-je savoir l'année de sortie des films portant le titre The Lost Echo Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Lost Echo Files'
# 🎯 Attendu : 2012
# ✅ Obtenu  : 2012
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me montrer l'année sortie des films intitulés The Hidden Memory Protocol, s'il vous plaît ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Memory Protocol'
# 🎯 Attendu : 2009
# ✅ Obtenu  : 2009
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir en quelle année sont sortis les films qui s'appellent The Dark Promise Affair.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Promise Affair'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui a réalisé les films intitulés The Golden Memory Protocol ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Memory Protocol'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire quelle année les films intitulés The Hidden Echo Saga sont sortis ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Echo Saga'
# 🎯 Attendu : 2002
# ✅ Obtenu  : 2002
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films appelés The Frozen Promise Story, s'il vous plaît ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Promise Story'
# 🎯 Attendu : Robert Zemeckis
# ✅ Obtenu  : Robert Zemeckis
# ✔️ Correct
#
# 🔎 Query : Montrez-moi, s'il vous plaît, qui est le réalisateur des films appelés The Dark Empire Code.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Dark Empire Code'
# 🎯 Attendu : Francis Ford Coppola
# ✅ Obtenu  : Francis Ford Coppola
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui est le réalisateur des films ayant pour titre The Last Memory Files.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Memory Files'
# 🎯 Attendu : David Fincher
# ✅ Obtenu  : David Fincher
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui réalise le film qui s'appelle The Golden Empire Chronicles.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Empire Chronicles'
# 🎯 Attendu : James Cameron
# ✅ Obtenu  : James Cameron
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui est le réalisateur des films intitulés The Infinite Journey Game ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Journey Game'
# 🎯 Attendu : Ridley Scott
# ✅ Obtenu  : Ridley Scott
# ✔️ Correct
#
# 🔎 Query : Merci de me donner l'année des films appelés The Hidden Echo Saga.
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Echo Saga'
# 🎯 Attendu : 2002
# ✅ Obtenu  : 2002
# ✔️ Correct
#
# 🔎 Query : Je souhaiterais savoir en quelle année les films intitulés The Last Journey Chronicles sont sortis.
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Journey Chronicles'
# 🎯 Attendu : 2005
# ✅ Obtenu  : 2005
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année du film The Frozen Memory Legacy, merci !
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Memory Legacy'
# 🎯 Attendu : 1990
# ✅ Obtenu  : 1990
# ✔️ Correct
#
# 🔎 Query : Je voudrais connaître le nom du réalisateur des films ayant pour titre The Hidden Echo Saga.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Echo Saga'
# 🎯 Attendu : Bong Joon-ho
# ✅ Obtenu  : Bong Joon-ho
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire quel est l'année des films intitulés The Hidden Empire Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Empire Chronicles'
# 🎯 Attendu : 2003
# ✅ Obtenu  : 2003
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous s'il vous plaît me communiquer l'année des films ayant pour titre The Golden Memory Protocol ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Memory Protocol'
# 🎯 Attendu : 1980
# ✅ Obtenu  : 1980
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir en quelle année les films intitulés The Broken Memory Affair sont sortis.
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Memory Affair'
# 🎯 Attendu : 2015
# ✅ Obtenu  : 2015
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur pour les films portant le titre The Burning Memory Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Memory Chronicles'
# 🎯 Attendu : Peter Jackson
# ✅ Obtenu  : Peter Jackson
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer les titres des films avec Emily Blunt et Anne Hathaway ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Emily Blunt' or acteur2 = 'Emily Blunt' or acteur3 = 'Emily Blunt')) AND ((acteur1 = 'Anne Hathaway' or acteur2 = 'Anne Hathaway' or acteur3 = 'Anne Hathaway'))
# 🎯 Attendu : The Dark Echo Story
# ✅ Obtenu  : The Dark Echo Story
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année des films portant le titre The Infinite Mission Project.
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Mission Project'
# 🎯 Attendu : 2009
# ✅ Obtenu  : 2009
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez me dire quelle est l'année des films intitulés The Burning Empire Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Empire Chronicles'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir qui a réalisé le film The Broken Shadow Files.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Shadow Files'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le réalisateur des films appelés The Golden Echo Saga ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Echo Saga'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire qui est le directeur du film The Broken Empire Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Empire Legacy'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire l'année des films intitulés The Broken Secret Protocol ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Secret Protocol'
# 🎯 Attendu : 2024
# ✅ Obtenu  : 2024
# ✔️ Correct
#
# 🔎 Query : Serait-il possible de connaître le réalisateur des films qui portent le titre The Burning Truth Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Truth Legacy'
# 🎯 Attendu : Greta Gerwig
# ✅ Obtenu  : Greta Gerwig
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez me donner le nom du réalisateur des films ayant pour titre The Infinite Truth Story ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Truth Story'
# 🎯 Attendu : Robert Zemeckis
# ✅ Obtenu  : Robert Zemeckis
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir quel est l'année des films portant le titre The Burning Echo Story.
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Echo Story'
# 🎯 Attendu : 1986
# ✅ Obtenu  : 1986
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous m'indiquer l'année de sortie des films intitulés The Golden Echo Protocol ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Echo Protocol'
# 🎯 Attendu : 1984
# ✅ Obtenu  : 1984
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez me dire les titres des films avec Brad Pitt et Keanu Reeves ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt')) AND ((acteur1 = 'Keanu Reeves' or acteur2 = 'Keanu Reeves' or acteur3 = 'Keanu Reeves'))
# 🎯 Attendu : The Golden Shadow Affair
# ✅ Obtenu  : The Golden Shadow Affair
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire en quelle année sont sortis les films nommés The Golden Memory Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Memory Code'
# 🎯 Attendu : 2022
# ✅ Obtenu  : 2022
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez me communiquer le nom du réalisateur des films appelés The Silent Echo Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Echo Legacy'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le réalisateur du film intitulé The Frozen Memory Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Memory Legacy'
# 🎯 Attendu : Guillermo del Toro
# ✅ Obtenu  : Guillermo del Toro
# ✔️ Correct
#
# 🔎 Query : Pourrais-tu me montrer les films de science-fiction avec Emma Stone ?
# 🧠 SQL → SELECT titre WHERE genre = 'Science-fiction' AND ((acteur1 = 'Emma Stone' or acteur2 = 'Emma Stone' or acteur3 = 'Emma Stone'))
# 🎯 Attendu : The Lost Truth Protocol
# ✅ Obtenu  : The Lost Truth Protocol
# ✔️ Correct
#
# 🔎 Query : Merci de me communiquer l'année des films qui portent le titre The Golden Journey Files.
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Journey Files'
# 🎯 Attendu : 1985
# ✅ Obtenu  : 1985
# ✔️ Correct
#
# 🔎 Query : Merci de me dire quand sont sortis les films intitulés The Last Memory Chronicles.
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Memory Chronicles'
# 🎯 Attendu : 1993
# ✅ Obtenu  : 1993
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir quelle année correspond au film intitulé The Dark Mission Story.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Mission Story'
# 🎯 Attendu : 1991
# ✅ Obtenu  : 1991
# ✔️ Correct
#
# 🔎 Query : Je cherche à savoir en quelle année sont sortis les films intitulés The Infinite Secret Project.
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Secret Project'
# 🎯 Attendu : 2017
# ✅ Obtenu  : 2017
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui réalise les films intitulés The Silent Mission Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Mission Legacy'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : Pourrais-tu me donner l'année des films qui s'appellent The Dark Secret Project ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Secret Project'
# 🎯 Attendu : 2006
# ✅ Obtenu  : 2006
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir l'année de sortie des films intitulés The Hidden Echo Saga, s'il vous plaît.
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Echo Saga'
# 🎯 Attendu : 2002
# ✅ Obtenu  : 2002
# ✔️ Correct
#
# 🔎 Query : Montrez-moi le nom du réalisateur des films appelés The Hidden Shadow Chronicles, s'il vous plaît.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Shadow Chronicles'
# 🎯 Attendu : Ron Howard
# ✅ Obtenu  : Ron Howard
# ✔️ Correct
#
# 🔎 Query : Cela m'intéresserait de connaître le réalisateur des films qui portent le titre The Hidden Empire Saga.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Empire Saga'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir quelle est l'année des films dont le titre est The Golden Mission Code.
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Mission Code'
# 🎯 Attendu : 1993
# ✅ Obtenu  : 1993
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui a réalisé les films qui portent le titre The Golden Truth Code ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Truth Code'
# 🎯 Attendu : Coen Brothers
# ✅ Obtenu  : Coen Brothers
# ✔️ Correct
#
# 🔎 Query : Merci de m'indiquer le nom du réalisateur pour les films The Golden Secret Saga.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Secret Saga'
# 🎯 Attendu : Quentin Tarantino
# ✅ Obtenu  : Quentin Tarantino
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui est le réalisateur des films ayant pour titre The Broken Promise Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Promise Chronicles'
# 🎯 Attendu : David Fincher
# ✅ Obtenu  : David Fincher
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films qui portent le titre The Burning Journey Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Journey Legacy'
# 🎯 Attendu : Guillermo del Toro
# ✅ Obtenu  : Guillermo del Toro
# ✔️ Correct
#
# 🔎 Query : Merci de me fournir l'année du film intitulé The Broken Promise Files.
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Promise Files'
# 🎯 Attendu : 1999
# ✅ Obtenu  : 1999
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire quelle est l'année des films avec le titre The Last Promise Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Promise Code'
# 🎯 Attendu : 1990
# ✅ Obtenu  : 1990
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous s'il vous plaît me fournir l'année des films dont le nom est The Dark Echo Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Echo Code'
# 🎯 Attendu : 2003
# ✅ Obtenu  : 2003
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui a réalisé les films ayant pour titre The Burning Journey Legacy.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Journey Legacy'
# 🎯 Attendu : Guillermo del Toro
# ✅ Obtenu  : Guillermo del Toro
# ✔️ Correct
#
# 🔎 Query : S'il te plaît, rappelle-moi l'année des films qui s'appellent The Burning Shadow Files.
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Shadow Files'
# 🎯 Attendu : 2004
# ✅ Obtenu  : 2004
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année de sortie du film The Broken Memory Game, s'il vous plaît.
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Memory Game'
# 🎯 Attendu : 2015
# ✅ Obtenu  : 2015
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur du film The Lost Dream Legacy, s'il vous plaît ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Dream Legacy'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Montrez-moi le réalisateur des films qui s'appellent The Golden Echo Saga, s'il vous plaît.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Echo Saga'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Pourrais-je savoir qui a réalisé les films intitulés The Infinite Promise Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Promise Chronicles'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire l'année des films ayant pour titre The Silent Dream Project ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Silent Dream Project'
# 🎯 Attendu : 1990
# ✅ Obtenu  : 1990
# ✔️ Correct
#
# 🔎 Query : Quel est le nom du réalisateur des films dont le titre est The Dark Promise Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Dark Promise Chronicles'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : Je souhaiterais connaître le réalisateur des films dont le titre est The Lost Echo Project.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Echo Project'
# 🎯 Attendu : George Lucas
# ✅ Obtenu  : George Lucas
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir quelle année les films s'appellent The Dark Promise Code.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Promise Code'
# 🎯 Attendu : 1993
# ✅ Obtenu  : 1993
# ✔️ Correct
#
# 🔎 Query : Je veux bien que vous me montriez les films où Anne Hathaway et Emily Blunt sont actrices.
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Anne Hathaway' or acteur2 = 'Anne Hathaway' or acteur3 = 'Anne Hathaway')) AND ((acteur1 = 'Emily Blunt' or acteur2 = 'Emily Blunt' or acteur3 = 'Emily Blunt'))
# 🎯 Attendu : The Dark Echo Story
# ✅ Obtenu  : The Dark Echo Story
# ✔️ Correct
#
# 🔎 Query : Montrez-moi qui est le réalisateur des films intitulés The Burning Memory Chronicles.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Memory Chronicles'
# 🎯 Attendu : Peter Jackson
# ✅ Obtenu  : Peter Jackson
# ✔️ Correct
#
# 🔎 Query : Pourrais-je savoir qui réalise le film The Lost Dream Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Dream Legacy'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films intitulés The Broken Promise Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Promise Files'
# 🎯 Attendu : James Cameron
# ✅ Obtenu  : James Cameron
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année de sortie du film The Frozen Mission Project, s'il vous plaît.
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Mission Project'
# 🎯 Attendu : 2000
# ✅ Obtenu  : 2000
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire quelle année c'est pour le film intitulé The Broken Echo Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Echo Code'
# 🎯 Attendu : 2019
# ✅ Obtenu  : 2019
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me donner le nom du réalisateur des films intitulés The Broken Promise Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Promise Files'
# 🎯 Attendu : James Cameron
# ✅ Obtenu  : James Cameron
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire qui est le réalisateur des films intitulés The Last Secret Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Secret Chronicles'
# 🎯 Attendu : Ridley Scott
# ✅ Obtenu  : Ridley Scott
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez m'indiquer l'année des films intitulés The Dark Echo Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Echo Chronicles'
# 🎯 Attendu : 1991
# ✅ Obtenu  : 1991
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez me fournir le nom du réalisateur des films intitulés The Golden Empire Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Empire Files'
# 🎯 Attendu : Greta Gerwig
# ✅ Obtenu  : Greta Gerwig
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir l'année des films qui portent le titre The Hidden Mission Story.
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Mission Story'
# 🎯 Attendu : 2018
# ✅ Obtenu  : 2018
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire l'année des films titulés The Golden Journey Saga ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Journey Saga'
# 🎯 Attendu : 2012
# ✅ Obtenu  : 2012
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir qui est le réalisateur des films nommés The Burning Journey Game.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Journey Game'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui est le réalisateur des films intitulés The Dark Journey Project ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Dark Journey Project'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui a réalisé le film The Silent Shadow Game ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Shadow Game'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui a réalisé les films intitulés The Silent Journey Files.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Journey Files'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me donner le titre des films dans lesquels Denzel Washington et Ryan Gosling apparaissent ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Denzel Washington' or acteur2 = 'Denzel Washington' or acteur3 = 'Denzel Washington')) AND ((acteur1 = 'Ryan Gosling' or acteur2 = 'Ryan Gosling' or acteur3 = 'Ryan Gosling'))
# 🎯 Attendu : The Broken Promise Saga
# ✅ Obtenu  : The Broken Promise Saga
# ✔️ Correct
#
# 🔎 Query : S'il te plaît, pourrais-tu me montrer le réalisateur de The Lost Secret Code ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Secret Code'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : S'il vous plaît, indiquez-moi l'année des films où le titre est The Dark Truth Code.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Truth Code'
# 🎯 Attendu : 1980
# ✅ Obtenu  : 1980
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer les titres des films avec Anne Hathaway et Emily Blunt ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Anne Hathaway' or acteur2 = 'Anne Hathaway' or acteur3 = 'Anne Hathaway')) AND ((acteur1 = 'Emily Blunt' or acteur2 = 'Emily Blunt' or acteur3 = 'Emily Blunt'))
# 🎯 Attendu : The Dark Echo Story
# ✅ Obtenu  : The Dark Echo Story
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me communiquer le nom du réalisateur pour The Lost Dream Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Dream Chronicles'
# 🎯 Attendu : George Lucas
# ✅ Obtenu  : George Lucas
# ✔️ Correct
#
# 🔎 Query : Qui est le directeur des films intitulés The Golden Dream Files, s'il vous plaît ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Dream Files'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Merci de m'indiquer l'année des films ayant pour titre The Hidden Memory Chronicles.
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Memory Chronicles'
# 🎯 Attendu : 2009
# ✅ Obtenu  : 2009
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année de sortie du film The Hidden Shadow Affair, s'il vous plaît.
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Shadow Affair'
# 🎯 Attendu : 1993
# ✅ Obtenu  : 1993
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous m'indiquer l'année des films intitulés The Infinite Promise Protocol ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Promise Protocol'
# 🎯 Attendu : 2005
# ✅ Obtenu  : 2005
# ✔️ Correct
#
# 🔎 Query : Est-ce que tu peux me montrer le réalisateur des films qui sont nommés The Last Journey Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Journey Affair'
# 🎯 Attendu : Steven Spielberg
# ✅ Obtenu  : Steven Spielberg
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer l'année des films intitulés The Burning Dream Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Dream Files'
# 🎯 Attendu : 1998
# ✅ Obtenu  : 1998
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui a réalisé le film The Broken Empire Legacy.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Empire Legacy'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire l'année des films intitulés The Last Dream Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Dream Code'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me donner les titres des films avec Charlize Theron et Matt Damon ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Charlize Theron' or acteur2 = 'Charlize Theron' or acteur3 = 'Charlize Theron')) AND ((acteur1 = 'Matt Damon' or acteur2 = 'Matt Damon' or acteur3 = 'Matt Damon'))
# 🎯 Attendu : The Silent Memory Saga
# ✅ Obtenu  : The Silent Memory Saga
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire l'année des films intitulés The Dark Promise Protocol ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Promise Protocol'
# 🎯 Attendu : 2003
# ✅ Obtenu  : 2003
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire l'année des films intitulés The Lost Mission Legacy ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Lost Mission Legacy'
# 🎯 Attendu : 1996
# ✅ Obtenu  : 1996
# ✔️ Correct
#
# 🔎 Query : Est-ce que quelqu'un peut m'indiquer le réalisateur des films nommés The Broken Echo Saga ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Echo Saga'
# 🎯 Attendu : Francis Ford Coppola
# ✅ Obtenu  : Francis Ford Coppola
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez me dire l'année des films qui s'appellent The Golden Secret Legacy ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Secret Legacy'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Merci de me préciser l'année des films qui portent le titre The Golden Echo Protocol.
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Echo Protocol'
# 🎯 Attendu : 1984
# ✅ Obtenu  : 1984
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez me dire l'année des films appelés The Last Memory Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Memory Code'
# 🎯 Attendu : 2019
# ✅ Obtenu  : 2019
# ✔️ Correct
#
# 🔎 Query : Qui est le directeur des films qui s'intitulent The Infinite Dream Protocol ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Dream Protocol'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : Montre-moi, s'il te plaît, le nom du réalisateur des films qui s'appellent The Dark Memory Affair.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Dark Memory Affair'
# 🎯 Attendu : Ron Howard
# ✅ Obtenu  : Ron Howard
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films qui portent le titre The Burning Empire Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Empire Files'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Je voudrais connaître l'année des films portant le titre The Burning Echo Files.
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Echo Files'
# 🎯 Attendu : 2024
# ✅ Obtenu  : 2024
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire l'année des films qui s'appellent The Silent Empire Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Silent Empire Files'
# 🎯 Attendu : 1996
# ✅ Obtenu  : 1996
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le réalisateur des films intitulés The Burning Empire Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Empire Files'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire les films mettant en vedette Denzel Washington et Chris Evans ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Denzel Washington' or acteur2 = 'Denzel Washington' or acteur3 = 'Denzel Washington')) AND ((acteur1 = 'Chris Evans' or acteur2 = 'Chris Evans' or acteur3 = 'Chris Evans'))
# 🎯 Attendu : The Hidden Secret Game
# ✅ Obtenu  : The Hidden Secret Game
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez me dire l'année des films qui portent le titre The Hidden Echo Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Echo Code'
# 🎯 Attendu : 1989
# ✅ Obtenu  : 1989
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui dirige les films The Frozen Empire Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Empire Affair'
# 🎯 Attendu : Greta Gerwig
# ✅ Obtenu  : Greta Gerwig
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le réalisateur des films intitulés The Burning Echo Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Echo Files'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui a réalisé le film The Lost Echo Project.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Echo Project'
# 🎯 Attendu : George Lucas
# ✅ Obtenu  : George Lucas
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films intitulés The Dark Shadow Saga, s'il vous plaît ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Dark Shadow Saga'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui est le réalisateur des films portant le titre The Silent Echo Game.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Echo Game'
# 🎯 Attendu : Peter Jackson
# ✅ Obtenu  : Peter Jackson
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me donner le nom du réalisateur des films qui portent le titre The Silent Promise Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Promise Legacy'
# 🎯 Attendu : Ridley Scott
# ✅ Obtenu  : Ridley Scott
# ✔️ Correct
#
# 🔎 Query : Merci de me dire qui a dirigé le film The Hidden Promise Code.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Promise Code'
# 🎯 Attendu : Bong Joon-ho
# ✅ Obtenu  : Bong Joon-ho
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir qui est le réalisateur pour les films intitulés The Frozen Truth Game.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Truth Game'
# 🎯 Attendu : Christopher Nolan
# ✅ Obtenu  : Christopher Nolan
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez me donner les titres des films où Natalie Portman et Jennifer Lawrence sont présentes ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Natalie Portman' or acteur2 = 'Natalie Portman' or acteur3 = 'Natalie Portman')) AND ((acteur1 = 'Jennifer Lawrence' or acteur2 = 'Jennifer Lawrence' or acteur3 = 'Jennifer Lawrence'))
# 🎯 Attendu : The Dark Memory Legacy
# ✅ Obtenu  : The Dark Memory Legacy
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire l'année des films qui portent le titre The Infinite Promise Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Promise Chronicles'
# 🎯 Attendu : 1998
# ✅ Obtenu  : 1998
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui est le réalisateur des films portant le nom The Infinite Truth Story ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Truth Story'
# 🎯 Attendu : Robert Zemeckis
# ✅ Obtenu  : Robert Zemeckis
# ✔️ Correct
#
# 🔎 Query : J'aimerais avoir la liste des films avec Morgan Freeman et Cate Blanchett.
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Morgan Freeman' or acteur2 = 'Morgan Freeman' or acteur3 = 'Morgan Freeman')) AND ((acteur1 = 'Cate Blanchett' or acteur2 = 'Cate Blanchett' or acteur3 = 'Cate Blanchett'))
# 🎯 Attendu : The Burning Shadow Project
# ✅ Obtenu  : The Burning Shadow Project
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous m'indiquer qui est le réalisateur des films The Last Secret Story ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Secret Story'
# 🎯 Attendu : Wes Anderson
# ✅ Obtenu  : Wes Anderson
# ✔️ Correct
#
# 🔎 Query : Montrez-moi le réalisateur des films appelés The Silent Mission Game, s'il vous plaît.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Mission Game'
# 🎯 Attendu : Coen Brothers
# ✅ Obtenu  : Coen Brothers
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez me dire l'année des films qui ont pour titre The Frozen Shadow Game ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Shadow Game'
# 🎯 Attendu : 1994
# ✅ Obtenu  : 1994
# ✔️ Correct
#
# 🔎 Query : Quels sont les films où l'on voit Chris Evans et Denzel Washington ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Chris Evans' or acteur2 = 'Chris Evans' or acteur3 = 'Chris Evans')) AND ((acteur1 = 'Denzel Washington' or acteur2 = 'Denzel Washington' or acteur3 = 'Denzel Washington'))
# 🎯 Attendu : The Hidden Secret Game
# ✅ Obtenu  : The Hidden Secret Game
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire quelle année c'est pour les films intitulés The Broken Memory Project ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Memory Project'
# 🎯 Attendu : 2024
# ✅ Obtenu  : 2024
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez me montrer qui est le réalisateur des films intitulés The Last Journey Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Journey Chronicles'
# 🎯 Attendu : Greta Gerwig
# ✅ Obtenu  : Greta Gerwig
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire en quelle année le film The Dark Mission Story est sorti ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Mission Story'
# 🎯 Attendu : 1991
# ✅ Obtenu  : 1991
# ✔️ Correct
#
# 🔎 Query : Est-ce que tu sais qui réalise les films intitulés The Dark Promise Game ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Dark Promise Game'
# 🎯 Attendu : Greta Gerwig
# ✅ Obtenu  : Greta Gerwig
# ✔️ Correct
#
# 🔎 Query : Quel est le réalisateur des films ayant pour titre The Golden Secret Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Secret Files'
# 🎯 Attendu : George Lucas
# ✅ Obtenu  : George Lucas
# ✔️ Correct
#
# 🔎 Query : Serait-il possible d'obtenir l'année des films qui portent le titre The Infinite Dream Protocol ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Dream Protocol'
# 🎯 Attendu : 2009
# ✅ Obtenu  : 2009
# ✔️ Correct
#
# 🔎 Query : Serait-il possible de connaître l'année du film qui s'appelle The Dark Promise Story ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Promise Story'
# 🎯 Attendu : 2011
# ✅ Obtenu  : 2011
# ✔️ Correct
#
# 🔎 Query : Quel est l'année de sortie des films ayant pour titre The Golden Dream Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Dream Chronicles'
# 🎯 Attendu : 2015
# ✅ Obtenu  : 2015
# ✔️ Correct
#
# 🔎 Query : Je souhaite connaître le réalisateur des films avec le titre The Last Secret Chronicles.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Secret Chronicles'
# 🎯 Attendu : Ridley Scott
# ✅ Obtenu  : Ridley Scott
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année des films intitulés The Last Promise Code, s'il vous plaît.
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Promise Code'
# 🎯 Attendu : 1990
# ✅ Obtenu  : 1990
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous indiquer l'année des films intitulés The Burning Empire Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Empire Chronicles'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir l'année des films qui portent le titre The Golden Dream Saga.
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Dream Saga'
# 🎯 Attendu : 2010
# ✅ Obtenu  : 2010
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire l'année des films intitulés The Burning Shadow Game ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Shadow Game'
# 🎯 Attendu : 1980
# ✅ Obtenu  : 1980
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez m'indiquer l'année des films intitulés The Lost Mission Legacy ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Lost Mission Legacy'
# 🎯 Attendu : 1996
# ✅ Obtenu  : 1996
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le réalisateur des films intitulés The Hidden Secret Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Secret Chronicles'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : Montrez-moi s'il vous plaît le réalisateur des films intitulés The Last Memory Story.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Memory Story'
# 🎯 Attendu : Steven Spielberg
# ✅ Obtenu  : Steven Spielberg
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer l'année des films intitulés The Hidden Secret Story ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Secret Story'
# 🎯 Attendu : 2007
# ✅ Obtenu  : 2007
# ✔️ Correct
#
# 🔎 Query : Quels sont les titres des films qui mettent en vedette Morgan Freeman et Robert De Niro ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Morgan Freeman' or acteur2 = 'Morgan Freeman' or acteur3 = 'Morgan Freeman')) AND ((acteur1 = 'Robert De Niro' or acteur2 = 'Robert De Niro' or acteur3 = 'Robert De Niro'))
# 🎯 Attendu : The Silent Dream Story
# ✅ Obtenu  : The Silent Dream Story
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez me fournir l'année des films sous le titre The Last Dream Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Dream Code'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Merci de m'indiquer l'année du film The Frozen Empire Affair.
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Empire Affair'
# 🎯 Attendu : 1982
# ✅ Obtenu  : 1982
# ✔️ Correct
#
# 🔎 Query : Montrez-moi s'il vous plaît qui est le réalisateur des films intitulés The Golden Memory Protocol.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Memory Protocol'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir quelle est l'année des films appelés The Hidden Dream Files.
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Dream Files'
# 🎯 Attendu : 2003
# ✅ Obtenu  : 2003
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me donner l'année de sortie des films The Last Empire Project ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Empire Project'
# 🎯 Attendu : 2000
# ✅ Obtenu  : 2000
# ✔️ Correct
#
# 🔎 Query : Auriez-vous la gentillesse de me dire l'année des films intitulés The Burning Echo Story ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Echo Story'
# 🎯 Attendu : 1986
# ✅ Obtenu  : 1986
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous m'indiquer l'année des films intitulés The Burning Journey Project ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Journey Project'
# 🎯 Attendu : 2011
# ✅ Obtenu  : 2011
# ✔️ Correct
#
# 🔎 Query : Est-ce que quelqu'un pourrait me dire qui est le réalisateur pour les films intitulés The Frozen Mission Saga ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Mission Saga'
# 🎯 Attendu : George Lucas
# ✅ Obtenu  : George Lucas
# ✔️ Correct
#
# 🔎 Query : Merci de m'indiquer l'année des films portant le titre The Burning Empire Affair.
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Empire Affair'
# 🎯 Attendu : 1991
# ✅ Obtenu  : 1991
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous afficher les titres des films où Hugh Jackman et Johnny Depp jouent ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Hugh Jackman' or acteur2 = 'Hugh Jackman' or acteur3 = 'Hugh Jackman')) AND ((acteur1 = 'Johnny Depp' or acteur2 = 'Johnny Depp' or acteur3 = 'Johnny Depp'))
# 🎯 Attendu : The Burning Promise Affair
# ✅ Obtenu  : The Burning Promise Affair
# ✔️ Correct
#
# 🔎 Query : Merci de m'informer de l'année des films qui portent le titre The Infinite Journey Game.
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Journey Game'
# 🎯 Attendu : 1982
# ✅ Obtenu  : 1982
# ✔️ Correct
#
# 🔎 Query : Montrez-moi l'année des films qui s'appellent The Infinite Journey Chronicles, s'il vous plaît.
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Journey Chronicles'
# 🎯 Attendu : 1984
# ✅ Obtenu  : 1984
# ✔️ Correct
#
# 🔎 Query : Peux-tu m'indiquer l'année des films ayant pour titre The Last Dream Game ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Dream Game'
# 🎯 Attendu : 1997
# ✅ Obtenu  : 1997
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer en quelle année est sorti le film intitulé The Hidden Truth Story ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Truth Story'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Peux-tu me renseigner sur l'année des films qui portent le titre The Broken Promise Game ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Promise Game'
# 🎯 Attendu : 1988
# ✅ Obtenu  : 1988
# ✔️ Correct
#
# 🔎 Query : Il serait bien de savoir en quelle année sont sortis les films appelés The Frozen Journey Protocol.
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Journey Protocol'
# 🎯 Attendu : 2005
# ✅ Obtenu  : 2005
# ✔️ Correct
#
# 🔎 Query : S'il vous plaît, indiquez-moi qui a réalisé le film The Hidden Mission Story.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Mission Story'
# 🎯 Attendu : Christopher Nolan
# ✅ Obtenu  : Christopher Nolan
# ✔️ Correct
#
# 🔎 Query : Pourrais-je connaître le nom du réalisateur des films nommés The Silent Truth Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Truth Files'
# 🎯 Attendu : James Cameron
# ✅ Obtenu  : James Cameron
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année des films ayant pour titre The Lost Dream Affair.
# 🧠 SQL → SELECT annee WHERE titre = 'The Lost Dream Affair'
# 🎯 Attendu : 1983
# ✅ Obtenu  : 1983
# ✔️ Correct
#
# 🔎 Query : Pourrais-tu me montrer qui dirige les films appelés The Dark Memory Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Dark Memory Affair'
# 🎯 Attendu : Ron Howard
# ✅ Obtenu  : Ron Howard
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous indiquer le réalisateur des films qui portent le titre The Hidden Echo Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Echo Chronicles'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire en quelle année sont sortis les films The Dark Journey Saga ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Journey Saga'
# 🎯 Attendu : 2024
# ✅ Obtenu  : 2024
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer qui est le réalisateur des films intitulés The Lost Promise Saga ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Promise Saga'
# 🎯 Attendu : Quentin Tarantino
# ✅ Obtenu  : Quentin Tarantino
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer l'année de sortie des films The Golden Journey Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Journey Files'
# 🎯 Attendu : 1985
# ✅ Obtenu  : 1985
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir en quelle année les films portés par le titre The Lost Shadow Saga sont sortis.
# 🧠 SQL → SELECT annee WHERE titre = 'The Lost Shadow Saga'
# 🎯 Attendu : 1985
# ✅ Obtenu  : 1985
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui est le réalisateur des films appelés The Lost Secret Game ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Secret Game'
# 🎯 Attendu : Coen Brothers
# ✅ Obtenu  : Coen Brothers
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'informer sur le réalisateur des films appelés The Infinite Journey Game ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Journey Game'
# 🎯 Attendu : Ridley Scott
# ✅ Obtenu  : Ridley Scott
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer qui est le réalisateur du film intitulé The Hidden Promise Code ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Promise Code'
# 🎯 Attendu : Bong Joon-ho
# ✅ Obtenu  : Bong Joon-ho
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez m'indiquer les films dans lesquels Robert De Niro et Keanu Reeves jouent ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Robert De Niro' or acteur2 = 'Robert De Niro' or acteur3 = 'Robert De Niro')) AND ((acteur1 = 'Keanu Reeves' or acteur2 = 'Keanu Reeves' or acteur3 = 'Keanu Reeves'))
# 🎯 Attendu : The Last Echo Game
# ✅ Obtenu  : The Last Echo Game
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui dirige le film The Golden Promise Affair.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Promise Affair'
# 🎯 Attendu : Steven Spielberg
# ✅ Obtenu  : Steven Spielberg
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me donner le nom du réalisateur des films intitulés The Golden Echo Saga ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Echo Saga'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films portant le titre The Lost Journey Story ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Journey Story'
# 🎯 Attendu : Ron Howard
# ✅ Obtenu  : Ron Howard
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer qui est le directeur du film intitulé The Last Dream Project ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Dream Project'
# 🎯 Attendu : David Fincher
# ✅ Obtenu  : David Fincher
# ✔️ Correct
#
# 🔎 Query : Je vous prie de bien vouloir me donner les titres des films dans lesquels jouent Hugh Jackman et Chris Evans.
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Hugh Jackman' or acteur2 = 'Hugh Jackman' or acteur3 = 'Hugh Jackman')) AND ((acteur1 = 'Chris Evans' or acteur2 = 'Chris Evans' or acteur3 = 'Chris Evans'))
# 🎯 Attendu : The Burning Shadow Saga
# ✅ Obtenu  : The Burning Shadow Saga
# ✔️ Correct
#
# 🔎 Query : Je souhaiterais connaître l'année des films dont le titre est The Lost Shadow Legacy.
# 🧠 SQL → SELECT annee WHERE titre = 'The Lost Shadow Legacy'
# 🎯 Attendu : 1982
# ✅ Obtenu  : 1982
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'informer sur l'année des films avec le titre The Dark Promise Story ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Promise Story'
# 🎯 Attendu : 2011
# ✅ Obtenu  : 2011
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pouvez me dire l'année des films appelés The Last Memory Saga ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Memory Saga'
# 🎯 Attendu : 1994
# ✅ Obtenu  : 1994
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous m'indiquer les films dans lesquels on voit Brad Pitt et Joaquin Phoenix ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt')) AND ((acteur1 = 'Joaquin Phoenix' or acteur2 = 'Joaquin Phoenix' or acteur3 = 'Joaquin Phoenix'))
# 🎯 Attendu : The Last Empire Story
# ✅ Obtenu  : The Last Empire Story
# ✔️ Correct
#
# 🔎 Query : Serait-il possible de connaître l'année de sortie des films The Dark Dream Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Dream Chronicles'
# 🎯 Attendu : 2021
# ✅ Obtenu  : 2021
# ✔️ Correct
#
# 🔎 Query : Serait-il possible d'avoir les titres des films auxquels Anne Hathaway et Emily Blunt participent ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Anne Hathaway' or acteur2 = 'Anne Hathaway' or acteur3 = 'Anne Hathaway')) AND ((acteur1 = 'Emily Blunt' or acteur2 = 'Emily Blunt' or acteur3 = 'Emily Blunt'))
# 🎯 Attendu : The Dark Echo Story
# ✅ Obtenu  : The Dark Echo Story
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le directeur des films intitulés The Hidden Empire Saga ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Empire Saga'
# 🎯 Attendu : Tim Burton
# ✅ Obtenu  : Tim Burton
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître le réalisateur des films appelés The Infinite Dream Protocol.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Dream Protocol'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir en quelle année sont sortis les films The Golden Echo Saga.
# ...
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Journey Game'
# 🎯 Attendu : 1982
# ✅ Obtenu  : 1982
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous indiquer l'année des films appelés The Hidden Empire Saga ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Empire Saga'
# 🎯 Attendu : 2011
# ✅ Obtenu  : 2011
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année des films intitulés The Dark Journey Saga.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Journey Saga'
# 🎯 Attendu : 2024
# ✅ Obtenu  : 2024
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous m'indiquer le réalisateur des films qui portent le nom de The Golden Echo Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Echo Files'
# 🎯 Attendu : George Lucas
# ✅ Obtenu  : George Lucas
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me montrer l'année des films avec le titre The Last Memory Saga, s'il vous plaît ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Memory Saga'
# 🎯 Attendu : 1994
# ✅ Obtenu  : 1994
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui est le réalisateur des films intitulés The Lost Dream Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Dream Affair'
# 🎯 Attendu : Francis Ford Coppola
# ✅ Obtenu  : Francis Ford Coppola
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me donner l'année des films sous le titre The Hidden Empire Saga ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Empire Saga'
# 🎯 Attendu : 2011
# ✅ Obtenu  : 2011
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir quelle année les films appelés The Burning Mission Chronicles sont sortis.
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Mission Chronicles'
# 🎯 Attendu : 2009
# ✅ Obtenu  : 2009
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire l'année des films intitulés The Broken Mission Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Mission Files'
# 🎯 Attendu : 2016
# ✅ Obtenu  : 2016
# ✔️ Correct
#
# 🔎 Query : Quelle est l'année du film appelé The Hidden Shadow Affair ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Shadow Affair'
# 🎯 Attendu : 1993
# ✅ Obtenu  : 1993
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous s'il vous plaît me dire l'année à laquelle le film The Hidden Truth Story a été réalisé ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Truth Story'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Je cherche à connaître l'année des films qui portent le titre The Dark Empire Legacy.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Empire Legacy'
# 🎯 Attendu : 2016
# ✅ Obtenu  : 2016
# ✔️ Correct
#
# 🔎 Query : Montre-moi le réalisateur des films intitulés The Lost Secret Code.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Secret Code'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui est le réalisateur des films qui portent le nom de The Last Memory Story.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Memory Story'
# 🎯 Attendu : Steven Spielberg
# ✅ Obtenu  : Steven Spielberg
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films portant le titre The Broken Promise Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Promise Chronicles'
# 🎯 Attendu : David Fincher
# ✅ Obtenu  : David Fincher
# ✔️ Correct
#
# 🔎 Query : Je voudrais savoir qui a dirigé le film intitulé The Frozen Journey Story.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Journey Story'
# 🎯 Attendu : Ron Howard
# ✅ Obtenu  : Ron Howard
# ✔️ Correct
#
# 🔎 Query : Quel est le réalisateur du film intitulé The Infinite Memory Legacy, s'il vous plaît ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Memory Legacy'
# 🎯 Attendu : Guillermo del Toro
# ✅ Obtenu  : Guillermo del Toro
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur derrière le film The Frozen Shadow Game ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Shadow Game'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : Merci de me fournir l'année des films intitulés The Dark Empire Affair.
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Empire Affair'
# 🎯 Attendu : 2000
# ✅ Obtenu  : 2000
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me montrer l'année de sortie des films appelés The Last Dream Code ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Dream Code'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Quelle est l'année du film appelé The Frozen Mission Project ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Mission Project'
# 🎯 Attendu : 2000
# ✅ Obtenu  : 2000
# ✔️ Correct
#
# 🔎 Query : Je souhaiterais savoir quelle est l'année des films intitulés The Golden Empire Chronicles.
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Empire Chronicles'
# 🎯 Attendu : 2013
# ✅ Obtenu  : 2013
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me montrer qui réalise les films intitulés The Frozen Dream Project ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Dream Project'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous pourriez m'indiquer l'année des films appelés The Dark Promise Affair ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Dark Promise Affair'
# 🎯 Attendu : 2014
# ✅ Obtenu  : 2014
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films The Broken Echo Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Echo Legacy'
# 🎯 Attendu : Steven Spielberg
# ✅ Obtenu  : Steven Spielberg
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me donner l'année des films intitulés The Frozen Journey Protocol ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Journey Protocol'
# 🎯 Attendu : 2005
# ✅ Obtenu  : 2005
# ✔️ Correct
#
# 🔎 Query : Je voudrais connaître le nom du réalisateur du film The Frozen Shadow Game, s'il vous plaît.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Frozen Shadow Game'
# 🎯 Attendu : Stanley Kubrick
# ✅ Obtenu  : Stanley Kubrick
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me renseigner sur l'année des films dont le titre est The Infinite Promise Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Promise Chronicles'
# 🎯 Attendu : 1998
# ✅ Obtenu  : 1998
# ✔️ Correct
#
# 🔎 Query : Pourrais-tu me montrer les titres des films avec Chris Evans et Denzel Washington ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Chris Evans' or acteur2 = 'Chris Evans' or acteur3 = 'Chris Evans')) AND ((acteur1 = 'Denzel Washington' or acteur2 = 'Denzel Washington' or acteur3 = 'Denzel Washington'))
# 🎯 Attendu : The Hidden Secret Game
# ✅ Obtenu  : The Hidden Secret Game
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître le nom du réalisateur des films ayant pour titre The Burning Memory Protocol.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Memory Protocol'
# 🎯 Attendu : Peter Jackson
# ✅ Obtenu  : Peter Jackson
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui a réalisé les films nommés The Broken Empire Files.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Empire Files'
# 🎯 Attendu : David Fincher
# ✅ Obtenu  : David Fincher
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître le nom du réalisateur des films qui portent le titre The Hidden Mission Files.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Mission Files'
# 🎯 Attendu : Bong Joon-ho
# ✅ Obtenu  : Bong Joon-ho
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire en quelle année sont sortis les films intitulés The Frozen Mission Saga ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Mission Saga'
# 🎯 Attendu : 2002
# ✅ Obtenu  : 2002
# ✔️ Correct
#
# 🔎 Query : Qui est le réalisateur des films nommés The Hidden Promise Project ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Promise Project'
# 🎯 Attendu : Coen Brothers
# ✅ Obtenu  : Coen Brothers
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer l'année des films intitulés The Broken Memory Affair ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Memory Affair'
# 🎯 Attendu : 2015
# ✅ Obtenu  : 2015
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir quels sont les films avec Brad Pitt et Keanu Reeves.
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt')) AND ((acteur1 = 'Keanu Reeves' or acteur2 = 'Keanu Reeves' or acteur3 = 'Keanu Reeves'))
# 🎯 Attendu : The Golden Shadow Affair
# ✅ Obtenu  : The Golden Shadow Affair
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire l'année des films nommés The Silent Echo Saga ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Silent Echo Saga'
# 🎯 Attendu : 2017
# ✅ Obtenu  : 2017
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me montrer le directeur des films sous le titre The Burning Empire Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Empire Files'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer qui est le réalisateur des films appelés The Hidden Mission Files ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Mission Files'
# 🎯 Attendu : Bong Joon-ho
# ✅ Obtenu  : Bong Joon-ho
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire en quelle année est sorti le film intitulé The Broken Promise Chronicles ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Promise Chronicles'
# 🎯 Attendu : 1982
# ✅ Obtenu  : 1982
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire quelle année les films intitulés The Last Mission Game ont été réalisés ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Mission Game'
# 🎯 Attendu : 1989
# ✅ Obtenu  : 1989
# ✔️ Correct
#
# 🔎 Query : S'il vous plaît, montrez-moi le réalisateur des films dont le titre est The Golden Echo Story.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Golden Echo Story'
# 🎯 Attendu : James Cameron
# ✅ Obtenu  : James Cameron
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année des films sous le titre The Broken Truth Files.
# 🧠 SQL → SELECT annee WHERE titre = 'The Broken Truth Files'
# 🎯 Attendu : 2010
# ✅ Obtenu  : 2010
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer l'année des films intitulés The Infinite Promise Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Promise Files'
# 🎯 Attendu : 2023
# ✅ Obtenu  : 2023
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'informer sur le réalisateur des films intitulés The Hidden Empire Chronicles ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Empire Chronicles'
# 🎯 Attendu : Ridley Scott
# ✅ Obtenu  : Ridley Scott
# ✔️ Correct
#
# 🔎 Query : Je voudrais connaître le réalisateur des films intitulés The Last Journey Chronicles, s'il vous plaît.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Last Journey Chronicles'
# 🎯 Attendu : Greta Gerwig
# ✅ Obtenu  : Greta Gerwig
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer l'année des films intitulés The Golden Echo Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Echo Files'
# 🎯 Attendu : 2003
# ✅ Obtenu  : 2003
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous m'indiquer l'année des films appelés The Frozen Journey Saga ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Frozen Journey Saga'
# 🎯 Attendu : 1983
# ✅ Obtenu  : 1983
# ✔️ Correct
#
# 🔎 Query : Je voudrais connaître l'année des films portant le nom de The Golden Truth Legacy.
# 🧠 SQL → SELECT annee WHERE titre = 'The Golden Truth Legacy'
# 🎯 Attendu : 2011
# ✅ Obtenu  : 2011
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me donner les titres des films avec Hugh Jackman et Zendaya ?
# 🧠 SQL → SELECT titre WHERE ((acteur1 = 'Hugh Jackman' or acteur2 = 'Hugh Jackman' or acteur3 = 'Hugh Jackman')) AND ((acteur1 = 'Zendaya' or acteur2 = 'Zendaya' or acteur3 = 'Zendaya'))
# 🎯 Attendu : The Infinite Truth Protocol
# ✅ Obtenu  : The Infinite Truth Protocol
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le réalisateur des films dont le titre est The Broken Echo Legacy ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Echo Legacy'
# 🎯 Attendu : Steven Spielberg
# ✅ Obtenu  : Steven Spielberg
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire qui est le réalisateur du film The Hidden Secret Story ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Secret Story'
# 🎯 Attendu : Bong Joon-ho
# ✅ Obtenu  : Bong Joon-ho
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître l'année des films ayant pour titre The Hidden Echo Files.
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Echo Files'
# 🎯 Attendu : 1992
# ✅ Obtenu  : 1992
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me fournir le nom du directeur des films appelés The Burning Journey Code ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Journey Code'
# 🎯 Attendu : Robert Zemeckis
# ✅ Obtenu  : Robert Zemeckis
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui a réalisé les films nommés The Infinite Promise Protocol.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Infinite Promise Protocol'
# 🎯 Attendu : Robert Zemeckis
# ✅ Obtenu  : Robert Zemeckis
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me donner le nom du réalisateur des films intitulés The Hidden Echo Story ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Echo Story'
# 🎯 Attendu : Peter Jackson
# ✅ Obtenu  : Peter Jackson
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui est le réalisateur des films appelés The Silent Empire Files.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Empire Files'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Montrez-moi le réalisateur de The Lost Dream Chronicles, s'il vous plaît.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Dream Chronicles'
# 🎯 Attendu : George Lucas
# ✅ Obtenu  : George Lucas
# ✔️ Correct
#
# 🔎 Query : Je voudrais connaître le nom du réalisateur des films intitulés The Silent Journey Files.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Journey Files'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous m'indiquer qui est le directeur des films portant le titre The Burning Secret Saga ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Burning Secret Saga'
# 🎯 Attendu : Robert Zemeckis
# ✅ Obtenu  : Robert Zemeckis
# ✔️ Correct
#
# 🔎 Query : Pourriez-vous me dire l'année des films intitulés The Last Secret Story ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Last Secret Story'
# 🎯 Attendu : 2017
# ✅ Obtenu  : 2017
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous me dire qui est le réalisateur pour le film The Broken Memory Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Memory Affair'
# 🎯 Attendu : Guillermo del Toro
# ✅ Obtenu  : Guillermo del Toro
# ✔️ Correct
#
# 🔎 Query : Montrez-moi, s'il vous plaît, l'année des films qui portent le nom de The Infinite Echo Affair.
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Echo Affair'
# 🎯 Attendu : 1986
# ✅ Obtenu  : 1986
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous indiquer l'année du film intitulé The Hidden Shadow Legacy ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Shadow Legacy'
# 🎯 Attendu : 1980
# ✅ Obtenu  : 1980
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire quelle année correspond aux films nommés The Burning Echo Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Burning Echo Files'
# 🎯 Attendu : 2024
# ✅ Obtenu  : 2024
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui a réalisé le film The Lost Promise Code.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Lost Promise Code'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : J'aimerais savoir qui a réalisé les films appelés The Hidden Secret Chronicles.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Hidden Secret Chronicles'
# 🎯 Attendu : Denis Villeneuve
# ✅ Obtenu  : Denis Villeneuve
# ✔️ Correct
#
# 🔎 Query : Est-ce que vous avez l'année des films intitulés The Infinite Memory Files ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Infinite Memory Files'
# 🎯 Attendu : 1991
# ✅ Obtenu  : 1991
# ✔️ Correct
#
# 🔎 Query : Pouvez-vous indiquer qui est le réalisateur des films intitulés The Silent Truth Project ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Silent Truth Project'
# 🎯 Attendu : Martin Scorsese
# ✅ Obtenu  : Martin Scorsese
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire depuis quelle année les films connus sous le titre The Hidden Echo Saga existent ?
# 🧠 SQL → SELECT annee WHERE titre = 'The Hidden Echo Saga'
# 🎯 Attendu : 2002
# ✅ Obtenu  : 2002
# ✔️ Correct
#
# 🔎 Query : J'aimerais connaître le nom du réalisateur des films qui s'appellent The Broken Promise Chronicles.
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Broken Promise Chronicles'
# 🎯 Attendu : David Fincher
# ✅ Obtenu  : David Fincher
# ✔️ Correct
#
# 🔎 Query : Peux-tu me dire qui est le réalisateur des films intitulés The Dark Dream Affair ?
# 🧠 SQL → SELECT realisateur WHERE titre = 'The Dark Dream Affair'
# 🎯 Attendu : George Lucas
# ✅ Obtenu  : George Lucas
# ✔️ Correct
#
# 📊 Évaluation terminée : 1691 / 1695 corrects
# 🎯 Précision : 99.76%

# %% [markdown]
# ##Evaluation qualitative :

# %%
import pandas as pd
import sqlite3
import re
import json
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Perceptron

# Charger données d'entraînement
with open("queries_french_para.json", encoding="utf-8") as f:
    data_train = json.load(f)

# Charger base films
df = pd.read_csv("base_films_500.csv")
conn = sqlite3.connect(":memory:")
df.to_sql("films", conn, index=False, if_exists="replace")

# Lexique
valeurs_concepts = {
    'titre': df['titre'].dropna().unique().tolist(),
    'realisateur': df['realisateur'].dropna().unique().tolist(),
    'annee': df['annee'].dropna().astype(str).unique().tolist(),
    'genre': df['genre'].dropna().unique().tolist(),
    'acteur1': df['acteur1'].dropna().unique().tolist(),
    'acteur2': df['acteur2'].dropna().unique().tolist(),
    'acteur3': df['acteur3'].dropna().unique().tolist()
}

# Analyse lexicale
def analyse_lexicale(requete, lexique):
    concepts_valeurs = []
    deja_vus = set()
    correspondances = []
    for concept, valeurs in lexique.items():
        for valeur in valeurs:
            if valeur.lower() in requete.lower():
                match = re.search(re.escape(valeur), requete, flags=re.IGNORECASE)
                if match:
                    correspondances.append((match.start(), valeur, concept))
    correspondances.sort()
    for _, valeur, concept in correspondances:
        if valeur.lower() not in deja_vus:
            deja_vus.add(valeur.lower())
            concept_label = "acteur" if concept.startswith("acteur") else concept
            concepts_valeurs.append((concept_label, valeur))
    return concepts_valeurs


def generer_where_sql(concepts_valeurs):
    clauses = []
    annees = []
    for concept, valeur in concepts_valeurs:
        if concept == "annee":
            annees.append(valeur)
        elif concept == "acteur":
            clause = f"((acteur1 = '{valeur}' or acteur2 = '{valeur}' or acteur3 = '{valeur}'))"
            clauses.append(clause)
        else:
            clause = f"{concept} = '{valeur}'"
            clauses.append(clause)
    if len(annees) == 2:
        an1, an2 = sorted(annees)
        clauses = [c for c in clauses if not c.startswith("annee")]
        clauses.append(f"annee between {an1} and {an2}")
    elif len(annees) == 1:
        clauses = [c for c in clauses if not c.startswith("annee")]
        clauses.append(f"annee = {annees[0]}")
    return " AND ".join(clauses)


def extraire_reponse_sql(select_pred, where_clause):
    sql = f"SELECT {select_pred} FROM films WHERE {where_clause};"
    try:
        result = pd.read_sql_query(sql, conn)
        if result.empty:
            return sql, "Aucun résultat"
        return sql, result.head(3).to_string(index=False)
    except Exception as e:
        return sql, f"Erreur SQL : {e}"


def extraire_labels(sql):
    select = re.search(r'select (.+?) from', sql, re.IGNORECASE)
    return select.group(1).strip().lower() if select else "UNKNOWN"


select_X, select_y = [], []
for entry in data_train:
    select_label = extraire_labels(entry["sql"])
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
    for phrase in phrases:
        select_X.append(phrase)
        select_y.append(select_label)

pipeline_select = Pipeline([
    ("vec", CountVectorizer()),
    ("clf", Perceptron())
])
pipeline_select.fit(select_X, select_y)


requetes_test = [
    "Quels sont les films réalisés par Wes Anderson ?",
    "Donne-moi les films de genre comédie.",
    "Quels films sont sortis en 2011 ?",
    "Affiche les films avec Brad Pitt.",
    "Quels sont les films d’action ?",
    "Montre moi les film de horreur.",
    "c koi les film avec denzel washigton ?",
    "Les films reyalisés par Martin scorcesse stp.",
    "Donne les film ou ya Emma Stone.",
    "Est ce qu'il y a des film en 1983 ?",
    "Quels films de science-fiction ont été réalisés après 2010 ?",
    "Trouve les films où jouent à la fois Denzel Washington et Tom Cruise.",
    "Liste des films de Peter Jackson avec Gal Gadot.",
    "Quels sont les films sortis entre 2000 et 2010 de genre comédie ?",
    "Tous les films réalisés par Denis Villeneuve avec au moins un acteur féminin mentionné.",
    "Quels films ont le mot “Promise” dans le titre ?",
    "Trouve les films où Chris Hemsworth est acteur principal.",
    "Quels sont les films réalisés par des réalisateurs dont le prénom est Ron ?",
    "Quels films ont pour actrice Jennifer Lawrence ?",
    "Liste des films avec plus d’un acteur masculin."
]

# Récapitulatif
recap = []

for req in requetes_test:
    concepts = analyse_lexicale(req, valeurs_concepts)
    select_pred = pipeline_select.predict([req])[0]
    where_clause = generer_where_sql(concepts)
    sql, result = extraire_reponse_sql(select_pred, where_clause)

    recap.append({
        "Requête naturelle": req,
        "Requête SQL générée": sql,
        "Résultat": result
    })

# Affichage final
df_recap = pd.DataFrame(recap)
pd.set_option("display.max_colwidth", None)
print("\n🧾 Récapitulatif des requêtes testées :")
display(df_recap)
# Out:
# 🧾 Récapitulatif des requêtes testées :
#                                                                           Requête naturelle  \
# 0                                          Quels sont les films réalisés par Wes Anderson ?
# 1                                                     Donne-moi les films de genre comédie.
# 2                                                         Quels films sont sortis en 2011 ?
# 3                                                         Affiche les films avec Brad Pitt.
# 4                                                           Quels sont les films d’action ?
# 5                                                           Montre moi les film de horreur.
# 6                                                    c koi les film avec denzel washigton ?
# 7                                             Les films reyalisés par Martin scorcesse stp.
# 8                                                          Donne les film ou ya Emma Stone.
# 9                                                       Est ce qu'il y a des film en 1983 ?
# 10                             Quels films de science-fiction ont été réalisés après 2010 ?
# 11                    Trouve les films où jouent à la fois Denzel Washington et Tom Cruise.
# 12                                         Liste des films de Peter Jackson avec Gal Gadot.
# 13                        Quels sont les films sortis entre 2000 et 2010 de genre comédie ?
# 14  Tous les films réalisés par Denis Villeneuve avec au moins un acteur féminin mentionné.
# 15                                         Quels films ont le mot “Promise” dans le titre ?
# 16                                Trouve les films où Chris Hemsworth est acteur principal.
# 17              Quels sont les films réalisés par des réalisateurs dont le prénom est Ron ?
# 18                                         Quels films ont pour actrice Jennifer Lawrence ?
# 19                                          Liste des films avec plus d’un acteur masculin.
#
#                                                                                                                                                                                                       Requête SQL générée  \
# 0                                                                                                                                                             SELECT titre FROM films WHERE realisateur = 'Wes Anderson';
# 1                                                                                                                                                                        SELECT titre FROM films WHERE genre = 'Comédie';
# 2                                                                                                                                                                             SELECT titre FROM films WHERE annee = 2011;
# 3                                                                                                              SELECT titre FROM films WHERE ((acteur1 = 'Brad Pitt' or acteur2 = 'Brad Pitt' or acteur3 = 'Brad Pitt'));
# 4                                                                                                                                                                         SELECT titre FROM films WHERE genre = 'Action';
# 5                                                                                                                                                                            SELECT * FROM films WHERE genre = 'Horreur';
# 6                                                                                                                                                                                         SELECT titre FROM films WHERE ;
# 7                                                                                                                                                                                         SELECT titre FROM films WHERE ;
# 8                                                                                                           SELECT titre FROM films WHERE ((acteur1 = 'Emma Stone' or acteur2 = 'Emma Stone' or acteur3 = 'Emma Stone'));
# 9                                                                                                                                                         SELECT acteur1, acteur2, acteur3 FROM films WHERE annee = 1983;
# 10                                                                                                                                              SELECT titre FROM films WHERE genre = 'Science-fiction' AND annee = 2010;
# 11  SELECT titre FROM films WHERE ((acteur1 = 'Denzel Washington' or acteur2 = 'Denzel Washington' or acteur3 = 'Denzel Washington')) AND ((acteur1 = 'Tom Cruise' or acteur2 = 'Tom Cruise' or acteur3 = 'Tom Cruise'));
# 12                                                                           SELECT titre FROM films WHERE realisateur = 'Peter Jackson' AND ((acteur1 = 'Gal Gadot' or acteur2 = 'Gal Gadot' or acteur3 = 'Gal Gadot'));
# 13                                                                                                                                           SELECT * FROM films WHERE genre = 'Comédie' AND annee between 2000 and 2010;
# 14                                                                                                                                                        SELECT titre FROM films WHERE realisateur = 'Denis Villeneuve';
# 15                                                                                                                                                                                  SELECT realisateur FROM films WHERE ;
# 16                                                                                           SELECT titre FROM films WHERE ((acteur1 = 'Chris Hemsworth' or acteur2 = 'Chris Hemsworth' or acteur3 = 'Chris Hemsworth'));
# 17                                                                                                                                                                                        SELECT titre FROM films WHERE ;
# 18                                                                                     SELECT titre FROM films WHERE ((acteur1 = 'Jennifer Lawrence' or acteur2 = 'Jennifer Lawrence' or acteur3 = 'Jennifer Lawrence'));
# 19                                                                                                                                                                                        SELECT titre FROM films WHERE ;
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                   Résultat
# 0                                                                                                                                                                                                                                                                                                                                                                   titre\nThe Burning Truth Project\nThe Infinite Journey Saga\n     The Frozen Echo Saga
# 1                                                                                                                                                                                                                                                                                                                                                                   titre\nThe Burning Truth Project\nThe Infinite Secret Files\n   The Hidden Shadow Saga
# 2                                                                                                                                                                                                                                                                                                                                                                         titre\nThe Hidden Promise Game\n The Hidden Empire Saga\nThe Burning Shadow Saga
# 3                                                                                                                                                                                                                                                                                                                                                                   titre\nThe Burning Truth Project\n    The Lost Promise Saga\n The Golden Shadow Affair
# 4                                                                                                                                                                                                                                                                                                                                                             titre\n  The Infinite Shadow Story\nThe Last Journey Chronicles\nThe Silent Mission Protocol
# 5                                                             titre  realisateur  annee   genre            acteur1         acteur2     acteur3\nThe Hidden Promise Game   Ron Howard   2011 Horreur    Chris Hemsworth Natalie Portman Emily Blunt\n The Burning Echo Story   Ron Howard   1986 Horreur Scarlett Johansson  Robert De Niro  Emma Stone\n   The Frozen Echo Saga Wes Anderson   2016 Horreur  Denzel Washington     Johnny Depp   Gal Gadot
# 6                                                                                                                                                                                                                                                                                                                                                           Erreur SQL : Execution failed on sql 'SELECT titre FROM films WHERE ;': near ";": syntax error
# 7                                                                                                                                                                                                                                                                                                                                                           Erreur SQL : Execution failed on sql 'SELECT titre FROM films WHERE ;': near ";": syntax error
# 8                                                                                                                                                                                                                                                                                                                                                                   titre\nThe Burning Truth Project\n   The Burning Echo Story\n   The Lost Promise Story
# 9                                                                                                                                                                                                                                                                                                   acteur1      acteur2   acteur3\n   Keanu Reeves   Matt Damon Gal Gadot\n   Mark Ruffalo Keanu Reeves Tom Hanks\nChris Hemsworth  Chris Evans Brad Pitt
# 10                                                                                                                                                                                                                                                                                                                                                                  titre\n   The Last Mission Files\nThe Infinite Shadow Story\n    The Lost Shadow Files
# 11                                                                                                                                                                                                                                                                                                                                                                  titre\nThe Last Promise Protocol\n       The Lost Echo Saga\nThe Burning Truth Project
# 12                                                                                                                                                                                                                                                                                                                                                            titre\n  The Infinite Shadow Story\nThe Dark Mission Chronicles\n     The Last Promise Files
# 13                      titre     realisateur  annee   genre        acteur1           acteur2            acteur3\nThe Burning Truth Project    Wes Anderson   2008 Comédie      Brad Pitt Denzel Washington         Emma Stone\nThe Infinite Secret Files Martin Scorsese   2004 Comédie Sandra Bullock   Chris Hemsworth  Jennifer Lawrence\n   The Hidden Shadow Saga   David Fincher   2008 Comédie   Hugh Jackman   Natalie Portman Scarlett Johansson
# 14                                                                                                                                                                                                                                                                                                                                                                  titre\nThe Last Promise Protocol\n    The Lost Mission Code\n The Frozen Secret Affair
# 15                                                                                                                                                                                                                                                                                                                                                    Erreur SQL : Execution failed on sql 'SELECT realisateur FROM films WHERE ;': near ";": syntax error
# 16                                                                                                                                                                                                                                                                                                                                                                  titre\n  The Hidden Promise Game\nThe Infinite Secret Files\n  The Golden Mission Code
# 17                                                                                                                                                                                                                                                                                                                                                          Erreur SQL : Execution failed on sql 'SELECT titre FROM films WHERE ;': near ";": syntax error
# 18                                                                                                                                                                                                                                                                                                                                                   titre\n     The Infinite Secret Files\n         The Lost Mission Code\nThe Burning Mission Chronicles
# 19                                                                                                                                                                                                                                                                                                                                                          Erreur SQL : Execution failed on sql 'SELECT titre FROM films WHERE ;': near ";": syntax error

# %% [markdown]
# #Question bonus :

# %%
import pandas as pd
import sqlite3
import re
import json
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Perceptron

# === Chargement
with open("queries_french_para.json", encoding="utf-8") as f:
    data_train = json.load(f)

df = pd.read_csv("base_films_500.csv")
conn = sqlite3.connect(":memory:")
df.to_sql("films", conn, index=False, if_exists="replace")

# === Lexique
valeurs_concepts = {
    'titre': df['titre'].dropna().unique().tolist(),
    'realisateur': df['realisateur'].dropna().unique().tolist(),
    'annee': df['annee'].dropna().astype(str).unique().tolist(),
    'genre': df['genre'].dropna().unique().tolist(),
    'acteur1': df['acteur1'].dropna().unique().tolist(),
    'acteur2': df['acteur2'].dropna().unique().tolist(),
    'acteur3': df['acteur3'].dropna().unique().tolist()
}

# === Analyse lexicale
def analyse_lexicale(requete, lexique):
    concepts_valeurs = []
    deja_vus = set()
    correspondances = []
    for concept, valeurs in lexique.items():
        for valeur in valeurs:
            if valeur.lower() in requete.lower():
                match = re.search(re.escape(valeur), requete, flags=re.IGNORECASE)
                if match:
                    correspondances.append((match.start(), valeur, concept))
    correspondances.sort()
    for _, valeur, concept in correspondances:
        if valeur.lower() not in deja_vus:
            deja_vus.add(valeur.lower())
            concept_label = "acteur" if concept.startswith("acteur") else concept
            concepts_valeurs.append((concept_label, valeur))
    return concepts_valeurs


def generer_where_sql(concepts_valeurs, requete_originale=None):
    clauses = []
    annees = []

    for concept, valeur in concepts_valeurs:
        if concept == "annee":
            annees.append(valeur)
        elif concept == "acteur":
            clause = f"((acteur1 = '{valeur}' or acteur2 = '{valeur}' or acteur3 = '{valeur}'))"
            clauses.append(clause)
        else:
            clause = f"{concept} = '{valeur}'"
            clauses.append(clause)


    if requete_originale:
        mots = re.findall(r"\b\w+\b", requete_originale)
        mots_utiles = [m for m in mots if len(m) > 3 and m.lower() not in ['quels', 'les', 'dans', 'avec', 'film', 'films', 'titre', 'mot', 'le']]
        valeurs_connues = [v.lower() for _, v in concepts_valeurs]
        for mot in mots_utiles:
            if mot.lower() not in valeurs_connues:
                clauses.append(f"titre LIKE '%{mot}%'")
                break

    if len(annees) == 2:
        an1, an2 = sorted(annees)
        clauses = [c for c in clauses if not c.startswith("annee")]
        clauses.append(f"annee BETWEEN {an1} AND {an2}")
    elif len(annees) == 1:
        clauses = [c for c in clauses if not c.startswith("annee")]
        clauses.append(f"annee = {annees[0]}")

    return " AND ".join(clauses)

# === SQL
def executer_sql(select, where):
    sql = f"SELECT {select} FROM films WHERE {where};"
    try:
        result = pd.read_sql_query(sql, conn)
        if result.empty:
            return sql, "Aucun résultat"
        return sql, result.head(5).to_string(index=False)
    except Exception as e:
        return sql, f"Erreur : {e}"

# === SELECT (Perceptron)
def extraire_labels(sql):
    match = re.search(r'select (.+?) from', sql, re.IGNORECASE)
    return match.group(1).strip().lower() if match else "UNKNOWN"

select_X, select_y = [], []
for entry in data_train:
    label = extraire_labels(entry["sql"])
    phrases = [entry["french"]["query_french"]] + entry["french"]["paraphrase_french"]
    for p in phrases:
        select_X.append(p)
        select_y.append(label)

pipeline_select = Pipeline([
    ("vec", CountVectorizer()),
    ("clf", Perceptron())
])
pipeline_select.fit(select_X, select_y)

# === Requête BONUS à tester
requete = "Quels films ont le mot Promise dans le titre ?"

concepts = analyse_lexicale(requete, valeurs_concepts)
select = pipeline_select.predict([requete])[0]
where = generer_where_sql(concepts, requete_originale=requete)
sql, result = executer_sql(select, where)

# === Affichage
print("📝 Requête naturelle :", requete)
print("📄 SQL générée :", sql)
print("\n📊 Résultat :")
print(result)
# Out:
# 📝 Requête naturelle : Quels films ont le mot Promise dans le titre ?
# 📄 SQL générée : SELECT realisateur FROM films WHERE titre LIKE '%Promise%';
#
# 📊 Résultat :
#       realisateur
#        Ron Howard
#  Denis Villeneuve
#   Stanley Kubrick
#   Robert Zemeckis
# Quentin Tarantino

# %% [markdown]
# Et tester aussi :
#
# "Quels films commencent par The ?"
#
# "Films dont le titre contient Shadow"
#
# "Liste des films où on voit 'Revenge'"
